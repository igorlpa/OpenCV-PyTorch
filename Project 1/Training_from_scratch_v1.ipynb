# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2: Get the Data](#step2)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#step5)
# - [Step 6. Display Mistakes](#step6)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 2: Train an Image Classifier From Scratch</font>
# As discussed in the previous notebook, the steps for training Neural Networks are:
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore and understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data preparation
# - Step 4 - Train a simple model on sample data and check the pipeline before proceeding to train the full network
# - Step 5 - Train on full data
# - Step 6 - Improve your model
#
# You have already been through Steps `1-4` in the previous notebook. Use them here as well.
#
# Here, you will implement Steps `5` & `6` from scratch. Design a model that achieves `>=85%` validation accuracy on the given dataset.
#
# There are 70 points for this notebook. The sections which carry marks are in Red.
#
# There are **70 points** for this notebook. <font style="color:red">The sections which carry marks are in Red.</font>

# %% [markdown]
# For GPU compute you can use Kaggle Kernels, Google Colab or any other service of your choice.
#
# After completing the assignment, upload and submit it on the portal for feedback.

# %% [markdown]
# <font style="color:red">Use the full data to train the network. You need to achieve 85% accuracy for validation data to successfully complete this assignment.</font>
#
#
# <font style="color:red">Just remember to build your own model, not use any pre-trained models/weights.</font>
#
#
# Upon completing the assignment, <font style="color:red">upload the notebook and the models folder on the portal for  feedback.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your problem </font><a name="step1"></a>
# Already covered in the previous notebook.

# %% [markdown]
# # <font style="color:blue">Step 2: Get the Data </font><a name="step2"></a>
#
# Already covered in the previous notebook.

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip
# Out:
# --2023-10-11 11:30:52--  https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra [following]
# --2023-10-11 11:30:52--  https://www.dropbox.com/sh/dl/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3ff8f223889e5b2c63f167bcd0.dl.dropboxusercontent.com/zip_download_get/BoxxZ2kv88M5SRwmzggpyUeTk1b3ViO-xPali6kC17O1807Y9xkmw6kQgPnbSKUiT6q5IOqsOnpmzyMdxyxXop13k3CM7T-aP4P8AJN8IGWGsQ?dl=1# [following]
# --2023-10-11 11:30:56--  https://uc3ff8f223889e5b2c63f167bcd0.dl.dropboxusercontent.com/zip_download_get/BoxxZ2kv88M5SRwmzggpyUeTk1b3ViO-xPali6kC17O1807Y9xkmw6kQgPnbSKUiT6q5IOqsOnpmzyMdxyxXop13k3CM7T-aP4P8AJN8IGWGsQ?dl=1
# Resolving uc3ff8f223889e5b2c63f167bcd0.dl.dropboxusercontent.com (uc3ff8f223889e5b2c63f167bcd0.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc3ff8f223889e5b2c63f167bcd0.dl.dropboxusercontent.com (uc3ff8f223889e5b2c63f167bcd0.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197683526 (189M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 188.53M  19.5MB/s    in 27s
#
# 2023-10-11 11:31:25 (6.92 MB/s) - ‘data.zip’ saved [197683526/197683526]

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
# !unzip -q data.zip
# Out:
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed

# %%
# !tree -d ./cat-dog-panda
# Out:
# ./cat-dog-panda
# ├── training
# │   ├── cat
# │   ├── dog
# │   └── panda
# └── validation
#     ├── cat
#     ├── dog
#     └── panda
#
# 8 directories

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation</font><a name="step3"></a>
# Already covered in the previous notebook.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %%
def image_augmented_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(0.1),
        transforms.RandomAutocontrast(0.1),
        transforms.RandomAdjustSharpness(2,0.1),
        #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.RandomRotation(20)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)
    
    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)
    
    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i] 
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]
    
    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)
    
    # var[X] = E[X**2] - E[X]**2
    
    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2
    
    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)
        
    std = var ** 0.5
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
# Data loader for generating batches of data to be used by the training routine

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:green">3.4. Prepare Data</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')
    test_data_path = os.path.join(data_root, 'validation')    
    
    mean, std = get_mean_std(train_data_path, num_workers)
    
    
    if data_augmentation:
        train_transformers = image_augmented_transforms(mean, std)
    else:
        train_transformers = image_common_transforms(mean, std)
    
    test_transformers = image_common_transforms(mean, std)
    
    
    train_dataset = datasets.ImageFolder(train_data_path, transform=train_transformers)  # dataset de treino
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, num_workers=num_workers)  # data loader de treino
    
    
    test_dataset = datasets.ImageFolder(test_data_path, transform=test_transformers)  # dataset de teste
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=False, num_workers=num_workers)  # data loader de teste
    
    
    return train_dataloader, test_dataloader

# %% [markdown]
# # <font style="color:blue">Step 4: Train Your Model</font><a name="step4"></a>
#
# Now, create the training pipeline, and train your model on the full data.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [20 Points]</font>
#
# To achieve good results, change the parameters given in these configurations. Score 20 points for all right choices.

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>
#
# Fix the seed (e.g., `21`) to get a reproducible result.

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 16 
    epochs_count: int = 200
    init_learning_rate: float = 0.005  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You are already familiar with the training function. No changes needed here.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        with torch.no_grad():
            output = model(data)
        
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Note: Before calling the train function, we calculate the validation loss, which we know should be close to $\log(\text{num_classes})$. Also, the accuracy should be close to $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available() and train_config.device == 'cuda':
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    print('treino: ', len(train_loader.dataset))    
    print('teste: ', len(test_loader.dataset))

    
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
        # scheduler step/ update learning rate
        if scheduler is not None:
            scheduler.step()        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:red">4.8. Define Model [20 Points]</font>
#
# Next, define the CNN model. Keep iterating. Do this by training various models. Just ,change the :
#
# - number of layers
# - parameters inside the layers
# - different types of layers

# %%
class MyModel(nn.Module):

    def __init__(self):
        super(MyModel, self).__init__()
        
        self._body = nn.Sequential(
            # input = 3 x 224 x 224
            nn.Conv2d(3, 10, 3, padding='same'),
            nn.BatchNorm2d(10),
            nn.ReLU(True),            
            # input = 16 x 224 x 224
            nn.Conv2d(10, 16, 3, padding='same'),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            # input = 32 x 112 x 112
            nn.Conv2d(16, 32, 3, padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Dropout(0.3),

        )
        
      
        self._classifier = nn.Sequential(
            nn.Linear(32*56*56, 128),
            nn.ReLU(True),
            nn.Dropout(0.3),
            
            nn.Linear(128, 64),            
            nn.ReLU(True),
            nn.Dropout(0.3),
            
            nn.Linear(64, 3)
        )


    
    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._classifier(x)
        return x

# %% [markdown]
# ## <font style="color:red">4.9. Training [20 Points]</font>
#
# Experiment with:
#
# - Optimizers and learning rate schedulers \[You can  get good results even without a learning rate scheduler\]
#
# - Regularization techniques like Data Augmentation, Dropout, BatchNorm

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()



# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)


### CHANGE HERE ###
decay_rate: float = 0.051 
lmbda = lambda epoch: 1/(1 + decay_rate * epoch)
# Scheduler
scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lmbda)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(10, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.3, inplace=False)
#   )
#   (_classifier): Sequential(
#     (0): Linear(in_features=100352, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=64, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=scheduler, data_augmentation=True)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
# treino:  2400
# teste:  600
#
# Test set: Average loss: 1.0981, Accuracy: 200/600 (33%)
#
# Initial Test Loss : 1.098109,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 3.049795 Acc: 0.3158
# Elapsed 17.26s, 17.26 s/epoch, 0.23 s/batch, ets 3435.12s
#
# Test set: Average loss: 1.0990, Accuracy: 200/600 (33%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 1.100880 Acc: 0.3258
# Elapsed 38.83s, 19.42 s/epoch, 0.26 s/batch, ets 3844.33s
#
# Test set: Average loss: 1.0988, Accuracy: 200/600 (33%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 1.102314 Acc: 0.3258
# Elapsed 59.97s, 19.99 s/epoch, 0.27 s/batch, ets 3937.73s
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Model Improved. Saving the Model...
#
# Epoch: 3
# Train Loss: 1.099773 Acc: 0.3242
# Elapsed 80.44s, 20.11 s/epoch, 0.27 s/batch, ets 3941.54s
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Model Improved. Saving the Model...
#
# Epoch: 4
# Train Loss: 1.103956 Acc: 0.3267
# Elapsed 101.82s, 20.36 s/epoch, 0.27 s/batch, ets 3970.87s
#
# Test set: Average loss: 1.0985, Accuracy: 200/600 (33%)
#
# Model Improved. Saving the Model...
#
# Epoch: 5
# Train Loss: 1.100028 Acc: 0.3258
# Elapsed 122.80s, 20.47 s/epoch, 0.27 s/batch, ets 3970.64s
#
# Test set: Average loss: 1.0986, Accuracy: 199/600 (33%)
#
# Epoch: 6
# Train Loss: 1.102537 Acc: 0.3429
# Elapsed 142.81s, 20.40 s/epoch, 0.27 s/batch, ets 3937.50s
#
# Test set: Average loss: 1.0985, Accuracy: 200/600 (33%)
#
# Model Improved. Saving the Model...
#
# Epoch: 7
# Train Loss: 1.099685 Acc: 0.3325
# Elapsed 163.86s, 20.48 s/epoch, 0.27 s/batch, ets 3932.56s
#
# Test set: Average loss: 1.0986, Accuracy: 200/600 (33%)
#
# Epoch: 8
# Train Loss: 1.099335 Acc: 0.3187
# Elapsed 184.70s, 20.52 s/epoch, 0.27 s/batch, ets 3919.64s
#
# Test set: Average loss: 1.0988, Accuracy: 200/600 (33%)
#
# Epoch: 9
# Train Loss: 1.105945 Acc: 0.3308
# Elapsed 205.00s, 20.50 s/epoch, 0.27 s/batch, ets 3894.91s
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Epoch: 10
# Train Loss: 1.099177 Acc: 0.3337
# Elapsed 225.56s, 20.51 s/epoch, 0.27 s/batch, ets 3875.53s
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Epoch: 11
# Train Loss: 1.098503 Acc: 0.3175
# Elapsed 246.21s, 20.52 s/epoch, 0.27 s/batch, ets 3857.23s
#
# Test set: Average loss: 1.0986, Accuracy: 200/600 (33%)
#
# Epoch: 12
# Train Loss: 1.098567 Acc: 0.3242
# Elapsed 266.54s, 20.50 s/epoch, 0.27 s/batch, ets 3834.09s
#
# Test set: Average loss: 1.0988, Accuracy: 200/600 (33%)
#
# Epoch: 13
# Train Loss: 1.099750 Acc: 0.3300
# Elapsed 287.21s, 20.52 s/epoch, 0.27 s/batch, ets 3815.84s
#
# Test set: Average loss: 1.0982, Accuracy: 203/600 (34%)
#
# Model Improved. Saving the Model...
#
# Epoch: 14
# Train Loss: 1.093372 Acc: 0.3513
# Elapsed 307.41s, 20.49 s/epoch, 0.27 s/batch, ets 3791.35s
#
# Test set: Average loss: 1.0990, Accuracy: 200/600 (33%)
#
# Epoch: 15
# Train Loss: 1.108280 Acc: 0.3412
# Elapsed 328.62s, 20.54 s/epoch, 0.27 s/batch, ets 3779.18s
#
# Test set: Average loss: 1.0991, Accuracy: 200/600 (33%)
#
# Epoch: 16
# Train Loss: 1.100793 Acc: 0.3171
# Elapsed 349.32s, 20.55 s/epoch, 0.27 s/batch, ets 3760.28s
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Epoch: 17
# Train Loss: 1.098826 Acc: 0.3221
# Elapsed 369.45s, 20.52 s/epoch, 0.27 s/batch, ets 3735.53s
#
# Test set: Average loss: 1.0986, Accuracy: 200/600 (33%)
#
# Epoch: 18
# Train Loss: 1.096967 Acc: 0.3438
# Elapsed 390.50s, 20.55 s/epoch, 0.27 s/batch, ets 3719.98s
#
# Test set: Average loss: 1.0985, Accuracy: 200/600 (33%)
#
# Epoch: 19
# Train Loss: 1.064772 Acc: 0.3762
# Elapsed 411.54s, 20.58 s/epoch, 0.27 s/batch, ets 3703.89s
#
# Test set: Average loss: 0.9539, Accuracy: 309/600 (52%)
#
# Model Improved. Saving the Model...
#
# Epoch: 20
# Train Loss: 1.045017 Acc: 0.4058
# Elapsed 432.52s, 20.60 s/epoch, 0.27 s/batch, ets 3686.69s
#
# Test set: Average loss: 0.9412, Accuracy: 244/600 (41%)
#
# Model Improved. Saving the Model...
#
# Epoch: 21
# Train Loss: 1.011164 Acc: 0.4379
# Elapsed 454.02s, 20.64 s/epoch, 0.28 s/batch, ets 3673.41s
#
# Test set: Average loss: 0.9064, Accuracy: 255/600 (42%)
#
# Model Improved. Saving the Model...
#
# Epoch: 22
# Train Loss: 0.961603 Acc: 0.4458
# Elapsed 475.45s, 20.67 s/epoch, 0.28 s/batch, ets 3658.91s
#
# Test set: Average loss: 0.8328, Accuracy: 330/600 (55%)
#
# Model Improved. Saving the Model...
#
# Epoch: 23
# Train Loss: 0.924023 Acc: 0.4983
# Elapsed 496.04s, 20.67 s/epoch, 0.28 s/batch, ets 3637.65s
#
# Test set: Average loss: 0.8923, Accuracy: 310/600 (52%)
#
# Epoch: 24
# Train Loss: 0.949996 Acc: 0.5142
# Elapsed 517.19s, 20.69 s/epoch, 0.28 s/batch, ets 3620.36s
#
# Test set: Average loss: 0.8111, Accuracy: 362/600 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 25
# Train Loss: 0.915078 Acc: 0.4988
# Elapsed 538.46s, 20.71 s/epoch, 0.28 s/batch, ets 3603.51s
#
# Test set: Average loss: 0.8157, Accuracy: 348/600 (58%)
#
# Epoch: 26
# Train Loss: 0.907194 Acc: 0.5233
# Elapsed 558.82s, 20.70 s/epoch, 0.28 s/batch, ets 3580.60s
#
# Test set: Average loss: 0.8060, Accuracy: 342/600 (57%)
#
# Model Improved. Saving the Model...
#
# Epoch: 27
# Train Loss: 0.887579 Acc: 0.5192
# Elapsed 579.71s, 20.70 s/epoch, 0.28 s/batch, ets 3561.05s
#
# Test set: Average loss: 0.7812, Accuracy: 346/600 (58%)
#
# Model Improved. Saving the Model...
#
# Epoch: 28
# Train Loss: 0.879518 Acc: 0.5413
# Elapsed 601.10s, 20.73 s/epoch, 0.28 s/batch, ets 3544.42s
#
# Test set: Average loss: 0.8191, Accuracy: 344/600 (57%)
#
# Epoch: 29
# Train Loss: 0.864610 Acc: 0.5521
# Elapsed 621.24s, 20.71 s/epoch, 0.28 s/batch, ets 3520.36s
#
# Test set: Average loss: 0.7718, Accuracy: 359/600 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 30
# Train Loss: 0.823859 Acc: 0.5713
# Elapsed 642.46s, 20.72 s/epoch, 0.28 s/batch, ets 3502.42s
#
# Test set: Average loss: 0.7491, Accuracy: 363/600 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 31
# Train Loss: 0.822230 Acc: 0.5550
# Elapsed 663.58s, 20.74 s/epoch, 0.28 s/batch, ets 3483.77s
#
# Test set: Average loss: 0.7487, Accuracy: 367/600 (61%)
#
# Model Improved. Saving the Model...
#
# Epoch: 32
# Train Loss: 0.816098 Acc: 0.5663
# Elapsed 684.48s, 20.74 s/epoch, 0.28 s/batch, ets 3463.88s
#
# Test set: Average loss: 0.7955, Accuracy: 353/600 (59%)
#
# Epoch: 33
# Train Loss: 0.813096 Acc: 0.5433
# Elapsed 705.43s, 20.75 s/epoch, 0.28 s/batch, ets 3444.18s
#
# Test set: Average loss: 0.7550, Accuracy: 357/600 (60%)
#
# Epoch: 34
# Train Loss: 0.789137 Acc: 0.5754
# Elapsed 726.46s, 20.76 s/epoch, 0.28 s/batch, ets 3424.72s
#
# Test set: Average loss: 0.7564, Accuracy: 348/600 (58%)
#
# Epoch: 35
# Train Loss: 0.792503 Acc: 0.5742
# Elapsed 746.64s, 20.74 s/epoch, 0.28 s/batch, ets 3401.36s
#
# Test set: Average loss: 0.7183, Accuracy: 363/600 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 36
# Train Loss: 0.778428 Acc: 0.5842
# Elapsed 767.97s, 20.76 s/epoch, 0.28 s/batch, ets 3383.21s
#
# Test set: Average loss: 0.7235, Accuracy: 391/600 (65%)
#
# Epoch: 37
# Train Loss: 0.773300 Acc: 0.5913
# Elapsed 788.99s, 20.76 s/epoch, 0.28 s/batch, ets 3363.57s
#
# Test set: Average loss: 0.7581, Accuracy: 370/600 (62%)
#
# Epoch: 38
# Train Loss: 0.761093 Acc: 0.6067
# Elapsed 809.35s, 20.75 s/epoch, 0.28 s/batch, ets 3341.17s
#
# Test set: Average loss: 0.6796, Accuracy: 389/600 (65%)
#
# Model Improved. Saving the Model...
#
# Epoch: 39
# Train Loss: 0.744464 Acc: 0.6004
# Elapsed 830.52s, 20.76 s/epoch, 0.28 s/batch, ets 3322.06s
#
# Test set: Average loss: 0.7674, Accuracy: 373/600 (62%)
#
# Epoch: 40
# Train Loss: 0.756578 Acc: 0.6008
# Elapsed 851.54s, 20.77 s/epoch, 0.28 s/batch, ets 3302.33s
#
# Test set: Average loss: 0.8078, Accuracy: 345/600 (58%)
#
# Epoch: 41
# Train Loss: 0.740324 Acc: 0.6246
# Elapsed 871.92s, 20.76 s/epoch, 0.28 s/batch, ets 3280.06s
#
# Test set: Average loss: 0.7420, Accuracy: 396/600 (66%)
#
# Epoch: 42
# Train Loss: 0.745356 Acc: 0.6008
# Elapsed 892.95s, 20.77 s/epoch, 0.28 s/batch, ets 3260.32s
#
# Test set: Average loss: 0.7106, Accuracy: 413/600 (69%)
#
# Epoch: 43
# Train Loss: 0.745308 Acc: 0.6208
# Elapsed 914.04s, 20.77 s/epoch, 0.28 s/batch, ets 3240.68s
#
# Test set: Average loss: 0.7516, Accuracy: 400/600 (67%)
#
# Epoch: 44
# Train Loss: 0.749029 Acc: 0.5917
# Elapsed 934.22s, 20.76 s/epoch, 0.28 s/batch, ets 3217.88s
#
# Test set: Average loss: 0.7769, Accuracy: 396/600 (66%)
#
# Epoch: 45
# Train Loss: 0.738182 Acc: 0.6296
# Elapsed 955.13s, 20.76 s/epoch, 0.28 s/batch, ets 3197.61s
#
# Test set: Average loss: 0.7504, Accuracy: 417/600 (70%)
#
# Epoch: 46
# Train Loss: 0.722907 Acc: 0.6371
# Elapsed 975.22s, 20.75 s/epoch, 0.28 s/batch, ets 3174.64s
#
# Test set: Average loss: 0.7087, Accuracy: 395/600 (66%)
#
# Epoch: 47
# Train Loss: 0.723609 Acc: 0.6375
# Elapsed 996.18s, 20.75 s/epoch, 0.28 s/batch, ets 3154.58s
#
# Test set: Average loss: 0.7559, Accuracy: 395/600 (66%)
#
# Epoch: 48
# Train Loss: 0.710596 Acc: 0.6279
# Elapsed 1017.32s, 20.76 s/epoch, 0.28 s/batch, ets 3135.02s
#
# Test set: Average loss: 0.7459, Accuracy: 407/600 (68%)
#
# Epoch: 49
# Train Loss: 0.703099 Acc: 0.6217
# Elapsed 1037.53s, 20.75 s/epoch, 0.28 s/batch, ets 3112.60s
#
# Test set: Average loss: 0.6883, Accuracy: 406/600 (68%)
#
# Epoch: 50
# Train Loss: 0.700300 Acc: 0.6275
# Elapsed 1058.65s, 20.76 s/epoch, 0.28 s/batch, ets 3092.91s
#
# Test set: Average loss: 0.6944, Accuracy: 387/600 (64%)
#
# Epoch: 51
# Train Loss: 0.699283 Acc: 0.6362
# Elapsed 1079.68s, 20.76 s/epoch, 0.28 s/batch, ets 3072.93s
#
# Test set: Average loss: 0.8083, Accuracy: 383/600 (64%)
#
# Epoch: 52
# Train Loss: 0.690975 Acc: 0.6288
# Elapsed 1100.04s, 20.76 s/epoch, 0.28 s/batch, ets 3051.05s
#
# Test set: Average loss: 0.7616, Accuracy: 401/600 (67%)
#
# Epoch: 53
# Train Loss: 0.693106 Acc: 0.6504
# Elapsed 1120.85s, 20.76 s/epoch, 0.28 s/batch, ets 3030.43s
#
# Test set: Average loss: 0.7745, Accuracy: 400/600 (67%)
#
# Epoch: 54
# Train Loss: 0.689358 Acc: 0.6462
# Elapsed 1141.60s, 20.76 s/epoch, 0.28 s/batch, ets 3009.67s
#
# Test set: Average loss: 0.7278, Accuracy: 401/600 (67%)
#
# Epoch: 55
# Train Loss: 0.685868 Acc: 0.6525
# Elapsed 1161.78s, 20.75 s/epoch, 0.28 s/batch, ets 2987.43s
#
# Test set: Average loss: 0.7768, Accuracy: 387/600 (64%)
#
# Epoch: 56
# Train Loss: 0.675401 Acc: 0.6517
# Elapsed 1182.61s, 20.75 s/epoch, 0.28 s/batch, ets 2966.90s
#
# Test set: Average loss: 0.6848, Accuracy: 408/600 (68%)
#
# Epoch: 57
# Train Loss: 0.657271 Acc: 0.6687
# Elapsed 1203.73s, 20.75 s/epoch, 0.28 s/batch, ets 2947.07s
#
# Test set: Average loss: 0.6896, Accuracy: 423/600 (70%)
#
# Epoch: 58
# Train Loss: 0.691583 Acc: 0.6542
# Elapsed 1223.74s, 20.74 s/epoch, 0.28 s/batch, ets 2924.54s
#
# Test set: Average loss: 0.7229, Accuracy: 412/600 (69%)
#
# Epoch: 59
# Train Loss: 0.677887 Acc: 0.6583
# Elapsed 1244.92s, 20.75 s/epoch, 0.28 s/batch, ets 2904.82s
#
# Test set: Average loss: 0.7132, Accuracy: 423/600 (70%)
#
# Epoch: 60
# Train Loss: 0.659618 Acc: 0.6558
# Elapsed 1265.73s, 20.75 s/epoch, 0.28 s/batch, ets 2884.21s
#
# Test set: Average loss: 0.6882, Accuracy: 416/600 (69%)
#
# Epoch: 61
# Train Loss: 0.678161 Acc: 0.6496
# Elapsed 1285.89s, 20.74 s/epoch, 0.28 s/batch, ets 2862.14s
#
# Test set: Average loss: 0.6930, Accuracy: 412/600 (69%)
#
# Epoch: 62
# Train Loss: 0.653697 Acc: 0.6671
# Elapsed 1306.74s, 20.74 s/epoch, 0.28 s/batch, ets 2841.63s
#
# Test set: Average loss: 0.7289, Accuracy: 422/600 (70%)
#
# Epoch: 63
# Train Loss: 0.643560 Acc: 0.6758
# Elapsed 1327.83s, 20.75 s/epoch, 0.28 s/batch, ets 2821.64s
#
# Test set: Average loss: 0.6958, Accuracy: 414/600 (69%)
#
# Epoch: 64
# Train Loss: 0.636890 Acc: 0.6763
# Elapsed 1348.08s, 20.74 s/epoch, 0.28 s/batch, ets 2799.86s
#
# Test set: Average loss: 0.6787, Accuracy: 413/600 (69%)
#
# Model Improved. Saving the Model...
#
# Epoch: 65
# Train Loss: 0.642969 Acc: 0.6850
# Elapsed 1369.63s, 20.75 s/epoch, 0.28 s/batch, ets 2780.76s
#
# Test set: Average loss: 0.6884, Accuracy: 424/600 (71%)
#
# Epoch: 66
# Train Loss: 0.625317 Acc: 0.6833
# Elapsed 1390.58s, 20.75 s/epoch, 0.28 s/batch, ets 2760.41s
#
# Test set: Average loss: 0.6540, Accuracy: 430/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 67
# Train Loss: 0.641374 Acc: 0.6729
# Elapsed 1411.03s, 20.75 s/epoch, 0.28 s/batch, ets 2739.05s
#
# Test set: Average loss: 0.6613, Accuracy: 418/600 (70%)
#
# Epoch: 68
# Train Loss: 0.617422 Acc: 0.6817
# Elapsed 1432.00s, 20.75 s/epoch, 0.28 s/batch, ets 2718.72s
#
# Test set: Average loss: 0.7204, Accuracy: 423/600 (70%)
#
# Epoch: 69
# Train Loss: 0.630897 Acc: 0.6758
# Elapsed 1452.08s, 20.74 s/epoch, 0.28 s/batch, ets 2696.73s
#
# Test set: Average loss: 0.6624, Accuracy: 415/600 (69%)
#
# Epoch: 70
# Train Loss: 0.637135 Acc: 0.6913
# Elapsed 1472.97s, 20.75 s/epoch, 0.28 s/batch, ets 2676.24s
#
# Test set: Average loss: 0.6867, Accuracy: 422/600 (70%)
#
# Epoch: 71
# Train Loss: 0.633412 Acc: 0.6954
# Elapsed 1494.13s, 20.75 s/epoch, 0.28 s/batch, ets 2656.22s
#
# Test set: Average loss: 0.6449, Accuracy: 414/600 (69%)
#
# Model Improved. Saving the Model...
#
# Epoch: 72
# Train Loss: 0.601450 Acc: 0.6917
# Elapsed 1514.62s, 20.75 s/epoch, 0.28 s/batch, ets 2635.02s
#
# Test set: Average loss: 0.7538, Accuracy: 409/600 (68%)
#
# Epoch: 73
# Train Loss: 0.639003 Acc: 0.6792
# Elapsed 1535.45s, 20.75 s/epoch, 0.28 s/batch, ets 2614.41s
#
# Test set: Average loss: 0.6537, Accuracy: 423/600 (70%)
#
# Epoch: 74
# Train Loss: 0.604620 Acc: 0.7013
# Elapsed 1556.32s, 20.75 s/epoch, 0.28 s/batch, ets 2593.87s
#
# Test set: Average loss: 0.6863, Accuracy: 435/600 (72%)
#
# Epoch: 75
# Train Loss: 0.591429 Acc: 0.7071
# Elapsed 1576.53s, 20.74 s/epoch, 0.28 s/batch, ets 2572.24s
#
# Test set: Average loss: 0.7486, Accuracy: 426/600 (71%)
#
# Epoch: 76
# Train Loss: 0.590873 Acc: 0.6967
# Elapsed 1597.46s, 20.75 s/epoch, 0.28 s/batch, ets 2551.79s
#
# Test set: Average loss: 0.6754, Accuracy: 429/600 (72%)
#
# Epoch: 77
# Train Loss: 0.612741 Acc: 0.7000
# Elapsed 1618.30s, 20.75 s/epoch, 0.28 s/batch, ets 2531.19s
#
# Test set: Average loss: 0.6990, Accuracy: 424/600 (71%)
#
# Epoch: 78
# Train Loss: 0.619120 Acc: 0.7046
# Elapsed 1638.70s, 20.74 s/epoch, 0.28 s/batch, ets 2509.91s
#
# Test set: Average loss: 0.6853, Accuracy: 432/600 (72%)
#
# Epoch: 79
# Train Loss: 0.582777 Acc: 0.7125
# Elapsed 1659.58s, 20.74 s/epoch, 0.28 s/batch, ets 2489.38s
#
# Test set: Average loss: 0.6946, Accuracy: 433/600 (72%)
#
# Epoch: 80
# Train Loss: 0.585123 Acc: 0.7171
# Elapsed 1680.25s, 20.74 s/epoch, 0.28 s/batch, ets 2468.52s
#
# Test set: Average loss: 0.6826, Accuracy: 433/600 (72%)
#
# Epoch: 81
# Train Loss: 0.602098 Acc: 0.7113
# Elapsed 1700.56s, 20.74 s/epoch, 0.28 s/batch, ets 2447.14s
#
# Test set: Average loss: 0.6930, Accuracy: 428/600 (71%)
#
# Epoch: 82
# Train Loss: 0.588576 Acc: 0.7133
# Elapsed 1721.50s, 20.74 s/epoch, 0.28 s/batch, ets 2426.70s
#
# Test set: Average loss: 0.6650, Accuracy: 423/600 (70%)
#
# Epoch: 83
# Train Loss: 0.589442 Acc: 0.7092
# Elapsed 1742.51s, 20.74 s/epoch, 0.28 s/batch, ets 2406.32s
#
# Test set: Average loss: 0.6706, Accuracy: 419/600 (70%)
#
# Epoch: 84
# Train Loss: 0.569336 Acc: 0.7221
# Elapsed 1762.68s, 20.74 s/epoch, 0.28 s/batch, ets 2384.80s
#
# Test set: Average loss: 0.6801, Accuracy: 434/600 (72%)
#
# Epoch: 85
# Train Loss: 0.578588 Acc: 0.7129
# Elapsed 1783.85s, 20.74 s/epoch, 0.28 s/batch, ets 2364.64s
#
# Test set: Average loss: 0.7092, Accuracy: 437/600 (73%)
#
# Epoch: 86
# Train Loss: 0.571538 Acc: 0.7058
# Elapsed 1804.79s, 20.74 s/epoch, 0.28 s/batch, ets 2344.15s
#
# Test set: Average loss: 0.6757, Accuracy: 438/600 (73%)
#
# Epoch: 87
# Train Loss: 0.555323 Acc: 0.7275
# Elapsed 1825.14s, 20.74 s/epoch, 0.28 s/batch, ets 2322.91s
#
# Test set: Average loss: 0.6722, Accuracy: 427/600 (71%)
#
# Epoch: 88
# Train Loss: 0.562752 Acc: 0.7271
# Elapsed 1846.08s, 20.74 s/epoch, 0.28 s/batch, ets 2302.41s
#
# Test set: Average loss: 0.6621, Accuracy: 441/600 (74%)
#
# Epoch: 89
# Train Loss: 0.561650 Acc: 0.7300
# Elapsed 1867.04s, 20.74 s/epoch, 0.28 s/batch, ets 2281.93s
#
# Test set: Average loss: 0.6699, Accuracy: 434/600 (72%)
#
# Epoch: 90
# Train Loss: 0.575030 Acc: 0.7167
# Elapsed 1887.23s, 20.74 s/epoch, 0.28 s/batch, ets 2260.52s
#
# Test set: Average loss: 0.7001, Accuracy: 435/600 (72%)
#
# Epoch: 91
# Train Loss: 0.574117 Acc: 0.7254
# Elapsed 1908.40s, 20.74 s/epoch, 0.28 s/batch, ets 2240.30s
#
# Test set: Average loss: 0.6769, Accuracy: 435/600 (72%)
#
# Epoch: 97
# Train Loss: 0.566750 Acc: 0.7354
# Elapsed 2032.94s, 20.74 s/epoch, 0.28 s/batch, ets 2115.92s
#
# Test set: Average loss: 0.6496, Accuracy: 434/600 (72%)
#
# Epoch: 98
# Train Loss: 0.538498 Acc: 0.7471
# Elapsed 2053.29s, 20.74 s/epoch, 0.28 s/batch, ets 2094.77s
#
# Test set: Average loss: 0.6749, Accuracy: 441/600 (74%)
#
# Epoch: 99
# Train Loss: 0.532245 Acc: 0.7421
# Elapsed 2074.59s, 20.75 s/epoch, 0.28 s/batch, ets 2074.59s
#
# Test set: Average loss: 0.6632, Accuracy: 435/600 (72%)
#
# Epoch: 100
# Train Loss: 0.535697 Acc: 0.7504
# Elapsed 2095.68s, 20.75 s/epoch, 0.28 s/batch, ets 2054.19s
#
# Test set: Average loss: 0.6846, Accuracy: 432/600 (72%)
#
# Epoch: 101
# Train Loss: 0.529045 Acc: 0.7421
# Elapsed 2116.00s, 20.75 s/epoch, 0.28 s/batch, ets 2033.02s
#
# Test set: Average loss: 0.7094, Accuracy: 435/600 (72%)
#
# Epoch: 102
# Train Loss: 0.507683 Acc: 0.7575
# Elapsed 2137.39s, 20.75 s/epoch, 0.28 s/batch, ets 2012.88s
#
# Test set: Average loss: 0.8185, Accuracy: 427/600 (71%)
#
# Epoch: 103
# Train Loss: 0.509284 Acc: 0.7633
# Elapsed 2158.34s, 20.75 s/epoch, 0.28 s/batch, ets 1992.31s
#
# Test set: Average loss: 0.7587, Accuracy: 434/600 (72%)
#
# Epoch: 104
# Train Loss: 0.491946 Acc: 0.7683
# Elapsed 2178.44s, 20.75 s/epoch, 0.28 s/batch, ets 1970.97s
#
# Test set: Average loss: 0.7836, Accuracy: 429/600 (72%)
#
# Epoch: 105
# Train Loss: 0.495588 Acc: 0.7771
# Elapsed 2199.80s, 20.75 s/epoch, 0.28 s/batch, ets 1950.77s
#
# Test set: Average loss: 0.7457, Accuracy: 434/600 (72%)
#
# Epoch: 106
# Train Loss: 0.538360 Acc: 0.7542
# Elapsed 2220.60s, 20.75 s/epoch, 0.28 s/batch, ets 1930.05s
#
# Test set: Average loss: 0.7290, Accuracy: 433/600 (72%)
#
# Epoch: 107
# Train Loss: 0.530606 Acc: 0.7471
# Elapsed 2240.85s, 20.75 s/epoch, 0.28 s/batch, ets 1908.87s
#
# Test set: Average loss: 0.7067, Accuracy: 428/600 (71%)
#
# Epoch: 108
# Train Loss: 0.512529 Acc: 0.7542
# Elapsed 2261.92s, 20.75 s/epoch, 0.28 s/batch, ets 1888.39s
#
# Test set: Average loss: 0.8334, Accuracy: 427/600 (71%)
#
# Epoch: 109
# Train Loss: 0.514925 Acc: 0.7583
# Elapsed 2282.74s, 20.75 s/epoch, 0.28 s/batch, ets 1867.69s
#
# Test set: Average loss: 0.7431, Accuracy: 434/600 (72%)
#
# Epoch: 110
# Train Loss: 0.500607 Acc: 0.7704
# Elapsed 2303.03s, 20.75 s/epoch, 0.28 s/batch, ets 1846.57s
#
# Test set: Average loss: 0.7219, Accuracy: 437/600 (73%)
#
# Epoch: 111
# Train Loss: 0.524981 Acc: 0.7546
# Elapsed 2324.19s, 20.75 s/epoch, 0.28 s/batch, ets 1826.15s
#
# Test set: Average loss: 0.7095, Accuracy: 442/600 (74%)
#
# Epoch: 112
# Train Loss: 0.504463 Acc: 0.7542
# Elapsed 2345.25s, 20.75 s/epoch, 0.28 s/batch, ets 1805.64s
#
# Test set: Average loss: 0.8321, Accuracy: 437/600 (73%)
#
# Epoch: 113
# Train Loss: 0.500010 Acc: 0.7596
# Elapsed 2365.86s, 20.75 s/epoch, 0.28 s/batch, ets 1784.77s
#
# Test set: Average loss: 0.8057, Accuracy: 440/600 (73%)
#
# Epoch: 114
# Train Loss: 0.487975 Acc: 0.7767
# Elapsed 2386.92s, 20.76 s/epoch, 0.28 s/batch, ets 1764.25s
#
# Test set: Average loss: 0.7873, Accuracy: 439/600 (73%)
#
# Epoch: 115
# Train Loss: 0.481278 Acc: 0.7900
# Elapsed 2407.85s, 20.76 s/epoch, 0.28 s/batch, ets 1743.61s
#
# Test set: Average loss: 0.8633, Accuracy: 441/600 (74%)
#
# Epoch: 116
# Train Loss: 0.492590 Acc: 0.7650
# Elapsed 2428.23s, 20.75 s/epoch, 0.28 s/batch, ets 1722.59s
#
# Test set: Average loss: 0.7683, Accuracy: 425/600 (71%)
#
# Epoch: 117
# Train Loss: 0.489831 Acc: 0.7708
# Elapsed 2449.29s, 20.76 s/epoch, 0.28 s/batch, ets 1702.05s
# Epoch: 120
# Train Loss: 0.483576 Acc: 0.7658
# Elapsed 2511.95s, 20.76 s/epoch, 0.28 s/batch, ets 1640.03s
#
# Test set: Average loss: 0.7051, Accuracy: 440/600 (73%)
#
# Epoch: 121
# Train Loss: 0.477116 Acc: 0.7725
# Elapsed 2532.17s, 20.76 s/epoch, 0.28 s/batch, ets 1618.93s
#
# Test set: Average loss: 0.7042, Accuracy: 433/600 (72%)
#
# Epoch: 122
# Train Loss: 0.475319 Acc: 0.7767
# Elapsed 2553.20s, 20.76 s/epoch, 0.28 s/batch, ets 1598.35s
#
# Test set: Average loss: 0.7303, Accuracy: 442/600 (74%)
#
# Epoch: 123
# Train Loss: 0.471990 Acc: 0.7825
# Elapsed 2574.51s, 20.76 s/epoch, 0.28 s/batch, ets 1577.92s
#
# Test set: Average loss: 0.7844, Accuracy: 438/600 (73%)
#
# Epoch: 124
# Train Loss: 0.473564 Acc: 0.7846
# Elapsed 2594.62s, 20.76 s/epoch, 0.28 s/batch, ets 1556.77s
#
# Test set: Average loss: 0.7233, Accuracy: 433/600 (72%)
#
# Epoch: 125
# Train Loss: 0.486988 Acc: 0.7821
# Elapsed 2615.69s, 20.76 s/epoch, 0.28 s/batch, ets 1536.20s
#
# Test set: Average loss: 0.7049, Accuracy: 430/600 (72%)
#
# Epoch: 126
# Train Loss: 0.481293 Acc: 0.7937
# Elapsed 2636.69s, 20.76 s/epoch, 0.28 s/batch, ets 1515.58s
#
# Test set: Average loss: 0.7595, Accuracy: 427/600 (71%)
#
# Epoch: 127
# Train Loss: 0.466433 Acc: 0.7825
# Elapsed 2656.78s, 20.76 s/epoch, 0.28 s/batch, ets 1494.44s
#
# Test set: Average loss: 0.7676, Accuracy: 428/600 (71%)
#
# Epoch: 128
# Train Loss: 0.447418 Acc: 0.7954
# Elapsed 2677.61s, 20.76 s/epoch, 0.28 s/batch, ets 1473.73s
#
# Test set: Average loss: 0.7539, Accuracy: 438/600 (73%)
#
# Epoch: 129
# Train Loss: 0.476573 Acc: 0.7883
# Elapsed 2698.92s, 20.76 s/epoch, 0.28 s/batch, ets 1453.27s
#
# Test set: Average loss: 0.7268, Accuracy: 438/600 (73%)
#
# Epoch: 130
# Train Loss: 0.471684 Acc: 0.7758
# Elapsed 2718.99s, 20.76 s/epoch, 0.28 s/batch, ets 1432.14s
#
# Test set: Average loss: 0.7800, Accuracy: 440/600 (73%)
#
# Epoch: 131
# Train Loss: 0.490736 Acc: 0.7758
# Elapsed 2739.76s, 20.76 s/epoch, 0.28 s/batch, ets 1411.39s
#
# Test set: Average loss: 0.7956, Accuracy: 435/600 (72%)
#
# Epoch: 132
# Train Loss: 0.454479 Acc: 0.7883
# Elapsed 2760.87s, 20.76 s/epoch, 0.28 s/batch, ets 1390.82s
#
# Test set: Average loss: 0.8154, Accuracy: 440/600 (73%)
#
# Epoch: 133
# Train Loss: 0.458182 Acc: 0.7933
# Elapsed 2781.25s, 20.76 s/epoch, 0.28 s/batch, ets 1369.87s
#
# Test set: Average loss: 0.8719, Accuracy: 431/600 (72%)
#
# Epoch: 134
# Train Loss: 0.463627 Acc: 0.7842
# Elapsed 2802.38s, 20.76 s/epoch, 0.28 s/batch, ets 1349.29s
#
# Test set: Average loss: 0.7922, Accuracy: 428/600 (71%)
#
# Epoch: 135
# Train Loss: 0.448266 Acc: 0.7904
# Elapsed 2823.25s, 20.76 s/epoch, 0.28 s/batch, ets 1328.59s
#
# Test set: Average loss: 0.7997, Accuracy: 436/600 (73%)
#
# Epoch: 136
# Train Loss: 0.462285 Acc: 0.7925
# Elapsed 2843.85s, 20.76 s/epoch, 0.28 s/batch, ets 1307.75s
#
# Test set: Average loss: 0.8448, Accuracy: 437/600 (73%)
#
# Epoch: 137
# Train Loss: 0.456429 Acc: 0.7883
# Elapsed 2865.20s, 20.76 s/epoch, 0.28 s/batch, ets 1287.27s
#
# Test set: Average loss: 0.7796, Accuracy: 432/600 (72%)
#
# Epoch: 138
# Train Loss: 0.448635 Acc: 0.7992
# Elapsed 2886.64s, 20.77 s/epoch, 0.28 s/batch, ets 1266.80s
#
# Test set: Average loss: 0.7707, Accuracy: 440/600 (73%)
#
# Epoch: 139
# Train Loss: 0.456231 Acc: 0.7829
# Elapsed 2907.23s, 20.77 s/epoch, 0.28 s/batch, ets 1245.96s
#
# Test set: Average loss: 0.8453, Accuracy: 442/600 (74%)
#
# Epoch: 140
# Train Loss: 0.455280 Acc: 0.7871
# Elapsed 2928.30s, 20.77 s/epoch, 0.28 s/batch, ets 1225.32s
#
# Test set: Average loss: 0.7908, Accuracy: 440/600 (73%)
#
# Epoch: 141
# Train Loss: 0.434965 Acc: 0.8083
# Elapsed 2949.35s, 20.77 s/epoch, 0.28 s/batch, ets 1204.66s
#
# Test set: Average loss: 0.7804, Accuracy: 436/600 (73%)
#
# Epoch: 142
# Train Loss: 0.448836 Acc: 0.7942
# Elapsed 2969.56s, 20.77 s/epoch, 0.28 s/batch, ets 1183.67s
#
# Test set: Average loss: 0.8735, Accuracy: 438/600 (73%)
#
# Epoch: 143
# Train Loss: 0.442078 Acc: 0.8000
# Elapsed 2990.34s, 20.77 s/epoch, 0.28 s/batch, ets 1162.91s
#
# Test set: Average loss: 0.8266, Accuracy: 445/600 (74%)
#
# Epoch: 144
# Train Loss: 0.450745 Acc: 0.8033
# Elapsed 3011.11s, 20.77 s/epoch, 0.28 s/batch, ets 1142.15s
#
# Test set: Average loss: 0.8214, Accuracy: 439/600 (73%)
#
# Epoch: 145
# Train Loss: 0.456148 Acc: 0.7846
# Elapsed 3031.44s, 20.76 s/epoch, 0.28 s/batch, ets 1121.22s
#
# Test set: Average loss: 0.8197, Accuracy: 442/600 (74%)
#
# Epoch: 146
# Train Loss: 0.433820 Acc: 0.8133
# Elapsed 3052.55s, 20.77 s/epoch, 0.28 s/batch, ets 1100.58s
#
# Test set: Average loss: 0.8393, Accuracy: 439/600 (73%)
#
# Epoch: 147
# Train Loss: 0.432400 Acc: 0.7963
# Elapsed 3072.57s, 20.76 s/epoch, 0.28 s/batch, ets 1079.55s
#
# Test set: Average loss: 0.8282, Accuracy: 439/600 (73%)
#
# Epoch: 148
# Train Loss: 0.443799 Acc: 0.7971
# Elapsed 3093.79s, 20.76 s/epoch, 0.28 s/batch, ets 1058.95s
#
# Test set: Average loss: 0.9332, Accuracy: 437/600 (73%)
#
# Epoch: 149
# Train Loss: 0.440358 Acc: 0.8058
# Elapsed 3114.56s, 20.76 s/epoch, 0.28 s/batch, ets 1038.19s
#
# Test set: Average loss: 0.8152, Accuracy: 439/600 (73%)
#
# Epoch: 150
# Train Loss: 0.426560 Acc: 0.8167
# Elapsed 3134.75s, 20.76 s/epoch, 0.28 s/batch, ets 1017.24s
#
# Test set: Average loss: 0.8391, Accuracy: 446/600 (74%)
#
# Epoch: 151
# Train Loss: 0.434090 Acc: 0.8063
# Elapsed 3155.83s, 20.76 s/epoch, 0.28 s/batch, ets 996.58s
#
# Test set: Average loss: 0.8137, Accuracy: 426/600 (71%)
#
# Epoch: 152
# Train Loss: 0.434092 Acc: 0.8146
# Elapsed 3176.89s, 20.76 s/epoch, 0.28 s/batch, ets 975.91s
#
# Test set: Average loss: 0.8464, Accuracy: 430/600 (72%)
#
# Epoch: 153
# Train Loss: 0.429552 Acc: 0.8125
# Elapsed 3196.95s, 20.76 s/epoch, 0.28 s/batch, ets 954.93s
#
# Test set: Average loss: 0.8341, Accuracy: 434/600 (72%)
#
# Epoch: 154
# Train Loss: 0.401684 Acc: 0.8300
# Elapsed 3217.50s, 20.76 s/epoch, 0.28 s/batch, ets 934.11s
#
# Test set: Average loss: 0.8764, Accuracy: 435/600 (72%)
#
# Epoch: 155
# Train Loss: 0.425887 Acc: 0.8075
# Elapsed 3238.60s, 20.76 s/epoch, 0.28 s/batch, ets 913.45s
#
# Test set: Average loss: 0.9402, Accuracy: 434/600 (72%)
#
# Epoch: 156
# Train Loss: 0.421922 Acc: 0.8100
# Elapsed 3258.68s, 20.76 s/epoch, 0.28 s/batch, ets 892.50s
#
# Test set: Average loss: 0.8782, Accuracy: 436/600 (73%)
#
# Epoch: 157
# Train Loss: 0.431177 Acc: 0.8075
# Elapsed 3279.86s, 20.76 s/epoch, 0.28 s/batch, ets 871.86s
#
# Test set: Average loss: 0.9051, Accuracy: 431/600 (72%)
#
# Epoch: 158
# Train Loss: 0.428878 Acc: 0.8187
# Elapsed 3300.83s, 20.76 s/epoch, 0.28 s/batch, ets 851.16s
#
# Test set: Average loss: 0.8542, Accuracy: 432/600 (72%)
#
# Epoch: 159
# Train Loss: 0.433345 Acc: 0.7946
# Elapsed 3321.02s, 20.76 s/epoch, 0.28 s/batch, ets 830.25s
#
# Test set: Average loss: 0.9019, Accuracy: 437/600 (73%)
#
# Epoch: 160
# Train Loss: 0.400020 Acc: 0.8233
# Elapsed 3341.85s, 20.76 s/epoch, 0.28 s/batch, ets 809.52s
#
# Test set: Average loss: 0.8786, Accuracy: 440/600 (73%)
#
# Epoch: 161
# Train Loss: 0.405034 Acc: 0.8246
# Elapsed 3362.88s, 20.76 s/epoch, 0.28 s/batch, ets 788.82s
#
# Test set: Average loss: 0.9531, Accuracy: 440/600 (73%)
#
# Epoch: 162
# Train Loss: 0.420442 Acc: 0.8279
# Elapsed 3383.17s, 20.76 s/epoch, 0.28 s/batch, ets 767.96s
#
# Test set: Average loss: 0.8727, Accuracy: 438/600 (73%)
#
# Epoch: 163
# Train Loss: 0.403922 Acc: 0.8187
# Elapsed 3404.01s, 20.76 s/epoch, 0.28 s/batch, ets 747.22s
#
# Test set: Average loss: 0.8910, Accuracy: 439/600 (73%)
#
# Epoch: 164
# Train Loss: 0.411827 Acc: 0.8083
# Elapsed 3424.11s, 20.75 s/epoch, 0.28 s/batch, ets 726.33s
#
# Test set: Average loss: 0.8675, Accuracy: 437/600 (73%)
#
# Epoch: 165
# Train Loss: 0.409856 Acc: 0.8271
# Elapsed 3444.76s, 20.75 s/epoch, 0.28 s/batch, ets 705.55s
#
# Test set: Average loss: 0.8138, Accuracy: 438/600 (73%)
#
# Epoch: 166
# Train Loss: 0.423497 Acc: 0.8242
# Elapsed 3465.79s, 20.75 s/epoch, 0.28 s/batch, ets 684.86s
#
# Test set: Average loss: 0.8667, Accuracy: 431/600 (72%)
#
# Epoch: 167
# Train Loss: 0.420387 Acc: 0.8200
# Elapsed 3486.00s, 20.75 s/epoch, 0.28 s/batch, ets 664.00s
#
# Test set: Average loss: 0.8201, Accuracy: 435/600 (72%)
#
# Epoch: 168
# Train Loss: 0.420316 Acc: 0.8154
# Elapsed 3507.06s, 20.75 s/epoch, 0.28 s/batch, ets 643.31s
#
# Test set: Average loss: 0.8801, Accuracy: 440/600 (73%)
#
# Epoch: 169
# Train Loss: 0.408452 Acc: 0.8158
# Elapsed 3527.90s, 20.75 s/epoch, 0.28 s/batch, ets 622.57s
#
# Test set: Average loss: 0.8601, Accuracy: 433/600 (72%)
#
# Epoch: 170
# Train Loss: 0.400922 Acc: 0.8258
# Elapsed 3547.96s, 20.75 s/epoch, 0.28 s/batch, ets 601.70s
#
# Test set: Average loss: 0.8484, Accuracy: 436/600 (73%)
#
# Epoch: 171
# Train Loss: 0.394882 Acc: 0.8308
# Elapsed 3569.01s, 20.75 s/epoch, 0.28 s/batch, ets 581.00s
#
# Test set: Average loss: 0.8376, Accuracy: 432/600 (72%)
#
# Epoch: 172
# Train Loss: 0.400685 Acc: 0.8271
# Elapsed 3589.93s, 20.75 s/epoch, 0.28 s/batch, ets 560.28s
#
# Test set: Average loss: 0.9549, Accuracy: 432/600 (72%)
#
# Epoch: 173
# Train Loss: 0.404673 Acc: 0.8263
# Elapsed 3610.16s, 20.75 s/epoch, 0.28 s/batch, ets 539.45s
#
# Test set: Average loss: 0.8011, Accuracy: 436/600 (73%)
#
# Epoch: 174
# Train Loss: 0.380757 Acc: 0.8279
# Elapsed 3631.04s, 20.75 s/epoch, 0.28 s/batch, ets 518.72s
#
# Test set: Average loss: 0.9645, Accuracy: 438/600 (73%)
#
# Epoch: 175
# Train Loss: 0.383962 Acc: 0.8283
# Elapsed 3651.94s, 20.75 s/epoch, 0.28 s/batch, ets 497.99s
#
# Test set: Average loss: 0.8235, Accuracy: 426/600 (71%)
#
# Epoch: 176
# Train Loss: 0.408271 Acc: 0.8313
# Elapsed 3672.04s, 20.75 s/epoch, 0.28 s/batch, ets 477.16s
#
# Test set: Average loss: 0.8906, Accuracy: 440/600 (73%)
#
# Epoch: 177
# Train Loss: 0.388598 Acc: 0.8400
# Elapsed 3692.79s, 20.75 s/epoch, 0.28 s/batch, ets 456.41s
#
# Test set: Average loss: 0.8564, Accuracy: 435/600 (72%)
#
# Epoch: 178
# Train Loss: 0.393841 Acc: 0.8258
# Elapsed 3713.71s, 20.75 s/epoch, 0.28 s/batch, ets 435.69s
#
# Test set: Average loss: 0.8108, Accuracy: 448/600 (75%)
#
# Epoch: 179
# Train Loss: 0.397278 Acc: 0.8333
# Elapsed 3733.89s, 20.74 s/epoch, 0.28 s/batch, ets 414.88s
#
# Test set: Average loss: 0.8868, Accuracy: 440/600 (73%)
#
# Epoch: 180
# Train Loss: 0.386944 Acc: 0.8292
# Elapsed 3754.96s, 20.75 s/epoch, 0.28 s/batch, ets 394.17s
#
# Test set: Average loss: 0.8940, Accuracy: 436/600 (73%)
#
# Epoch: 181
# Train Loss: 0.395447 Acc: 0.8271
# Elapsed 3775.65s, 20.75 s/epoch, 0.28 s/batch, ets 373.42s
#
# Test set: Average loss: 0.8548, Accuracy: 439/600 (73%)
#
# Epoch: 182
# Train Loss: 0.396556 Acc: 0.8208
# Elapsed 3795.69s, 20.74 s/epoch, 0.28 s/batch, ets 352.60s
#
# Test set: Average loss: 0.8528, Accuracy: 444/600 (74%)
#
# Epoch: 183
# Train Loss: 0.376597 Acc: 0.8417
# Elapsed 3816.59s, 20.74 s/epoch, 0.28 s/batch, ets 331.88s
#
# Test set: Average loss: 0.8452, Accuracy: 432/600 (72%)
#
# Epoch: 184
# Train Loss: 0.376879 Acc: 0.8358
# Elapsed 3836.92s, 20.74 s/epoch, 0.28 s/batch, ets 311.10s
#
# Test set: Average loss: 0.9216, Accuracy: 435/600 (72%)
#
# Epoch: 185
# Train Loss: 0.373820 Acc: 0.8333
# Elapsed 3857.71s, 20.74 s/epoch, 0.28 s/batch, ets 290.37s
#
# Test set: Average loss: 0.9436, Accuracy: 430/600 (72%)
#
# Epoch: 186
# Train Loss: 0.373177 Acc: 0.8404
# Elapsed 3878.60s, 20.74 s/epoch, 0.28 s/batch, ets 269.63s
#
# Test set: Average loss: 0.9949, Accuracy: 429/600 (72%)
#
# Epoch: 187
# Train Loss: 0.372856 Acc: 0.8438
# Elapsed 3898.99s, 20.74 s/epoch, 0.28 s/batch, ets 248.87s
#
# Test set: Average loss: 0.8881, Accuracy: 433/600 (72%)
#
# Epoch: 188
# Train Loss: 0.361608 Acc: 0.8438
# Elapsed 3920.04s, 20.74 s/epoch, 0.28 s/batch, ets 228.15s
#
# Test set: Average loss: 0.8538, Accuracy: 443/600 (74%)
#
# Epoch: 189
# Train Loss: 0.377190 Acc: 0.8383
# Elapsed 3940.84s, 20.74 s/epoch, 0.28 s/batch, ets 207.41s
#
# Test set: Average loss: 0.8712, Accuracy: 441/600 (74%)
#
# Epoch: 190
# Train Loss: 0.369206 Acc: 0.8354
# Elapsed 3961.00s, 20.74 s/epoch, 0.28 s/batch, ets 186.64s
#
# Test set: Average loss: 0.8837, Accuracy: 428/600 (71%)
#
# Epoch: 191
# Train Loss: 0.388293 Acc: 0.8367
# Elapsed 3982.07s, 20.74 s/epoch, 0.28 s/batch, ets 165.92s
#
# Test set: Average loss: 0.8881, Accuracy: 427/600 (71%)
#
# Epoch: 192
# Train Loss: 0.374972 Acc: 0.8363
# Elapsed 4003.07s, 20.74 s/epoch, 0.28 s/batch, ets 145.19s
#
# Test set: Average loss: 0.7936, Accuracy: 443/600 (74%)
#
# Epoch: 193
# Train Loss: 0.368725 Acc: 0.8433
# Elapsed 4023.09s, 20.74 s/epoch, 0.28 s/batch, ets 124.43s
#
# Test set: Average loss: 0.8221, Accuracy: 441/600 (74%)
#
# Epoch: 194
# Train Loss: 0.353809 Acc: 0.8421
# Elapsed 4044.01s, 20.74 s/epoch, 0.28 s/batch, ets 103.69s
#
# Test set: Average loss: 0.9142, Accuracy: 441/600 (74%)
#
# Epoch: 195
# Train Loss: 0.366525 Acc: 0.8358
# Elapsed 4064.91s, 20.74 s/epoch, 0.28 s/batch, ets 82.96s
#
# Test set: Average loss: 0.8808, Accuracy: 448/600 (75%)
#
# Epoch: 196
# Train Loss: 0.379570 Acc: 0.8329
# Elapsed 4085.11s, 20.74 s/epoch, 0.28 s/batch, ets 62.21s
#
# Test set: Average loss: 0.9652, Accuracy: 437/600 (73%)
#
# Epoch: 197
# Train Loss: 0.365879 Acc: 0.8433
# Elapsed 4106.27s, 20.74 s/epoch, 0.28 s/batch, ets 41.48s
#
# Test set: Average loss: 0.9296, Accuracy: 440/600 (73%)
#
# Epoch: 198
# Train Loss: 0.363050 Acc: 0.8363
# Elapsed 4127.43s, 20.74 s/epoch, 0.28 s/batch, ets 20.74s
#
# Test set: Average loss: 0.9702, Accuracy: 438/600 (73%)
#
# Epoch: 199
# Train Loss: 0.368031 Acc: 0.8479
# Elapsed 4147.79s, 20.74 s/epoch, 0.28 s/batch, ets 0.00s
#
# Test set: Average loss: 0.8606, Accuracy: 440/600 (73%)
#
# Total time: 4150.72, Best Loss: 0.645

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">Step 5. Sample Prediction</font><a name="step5"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    data = batch_input.to(device)
    
    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %% [markdown]
# # <font style="color:red">Step 6. Display Confusion Matrix [10 Points]</font><a name="step6"></a>
#
# Display the confusion matrix for the above problem(Refer to the earlier lectures on Performance Metrics).
#
#
# The output should resemble this:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/02/c3_w5_sample_confusion_matrix.png' width=600>

# %%
training_configuration = TrainingConfiguration()

# data loader
train_loader, test_loader = get_data(
    batch_size=16,
    data_root=training_configuration.data_root,
    num_workers=2,
    data_augmentation=True
)


model.eval()
test_loss = 0
count_corect_predictions = 0
y =[]
y_pred =[]
for data, target in test_loader:
    indx_target = target.clone()
    data = data.to(train_config.device)

    target = target.to(train_config.device)

    with torch.no_grad():
        output = model(data)

    # add loss for each mini batch
    test_loss += F.cross_entropy(output, target).item()

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the index of the max probability
    pred = prob.data.max(dim=1)[1] 
    
    # resultados
    #y.append(indx_target.tolist())
    #y_pred.append(pred.tolist())
    y = y + indx_target.tolist()
    y_pred = y_pred + pred.tolist()

    # add correct prediction count
    count_corect_predictions += pred.cpu().eq(indx_target).sum()

# average over number of mini-batches
test_loss = test_loss / len(test_loader)  

# average over number of dataset
accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['cat','dog', 'panda'])
disp.plot()

# %% [markdown]
# Upon completing the assignment,  <font style="color:red">pload the 2 notebooks and the models folder on the portal for feedback.</font>
