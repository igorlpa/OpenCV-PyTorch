# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2: Get the Data](#step2)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#step5)
# - [Step 6. Display Mistakes](#step6)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 2: Train an Image Classifier From Scratch</font>
# As discussed in the previous notebook, the steps for training Neural Networks are:
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore and understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data preparation
# - Step 4 - Train a simple model on sample data and check the pipeline before proceeding to train the full network
# - Step 5 - Train on full data
# - Step 6 - Improve your model
#
# You have already been through Steps `1-4` in the previous notebook. Use them here as well.
#
# Here, you will implement Steps `5` & `6` from scratch. Design a model that achieves `>=85%` validation accuracy on the given dataset.
#
# There are 70 points for this notebook. The sections which carry marks are in Red.
#
# There are **70 points** for this notebook. <font style="color:red">The sections which carry marks are in Red.</font>

# %% [markdown]
# For GPU compute you can use Kaggle Kernels, Google Colab or any other service of your choice.
#
# After completing the assignment, upload and submit it on the portal for feedback.

# %% [markdown]
# <font style="color:red">Use the full data to train the network. You need to achieve 85% accuracy for validation data to successfully complete this assignment.</font>
#
#
# <font style="color:red">Just remember to build your own model, not use any pre-trained models/weights.</font>
#
#
# Upon completing the assignment, <font style="color:red">upload the notebook and the models folder on the portal for  feedback.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your problem </font><a name="step1"></a>
# Already covered in the previous notebook.

# %% [markdown]
# # <font style="color:blue">Step 2: Get the Data </font><a name="step2"></a>
#
# Already covered in the previous notebook.

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip
# Out:
# --2023-10-13 11:33:47--  https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra [following]
# --2023-10-13 11:33:47--  https://www.dropbox.com/sh/dl/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc470df8ee8261c87e0c35713cd1.dl.dropboxusercontent.com/zip_download_get/Bo51gEHvpYCk8SQzHzlR-8mrCebRiOxKPMnXP48mf8thtv7oAO1nLKPK60IlTFkObdwnSWpTp1xXwSBMVsd0Mt-cfNnQ53bI_L9TNYOmBqk7Nw?dl=1# [following]
# --2023-10-13 11:33:51--  https://uc470df8ee8261c87e0c35713cd1.dl.dropboxusercontent.com/zip_download_get/Bo51gEHvpYCk8SQzHzlR-8mrCebRiOxKPMnXP48mf8thtv7oAO1nLKPK60IlTFkObdwnSWpTp1xXwSBMVsd0Mt-cfNnQ53bI_L9TNYOmBqk7Nw?dl=1
# Resolving uc470df8ee8261c87e0c35713cd1.dl.dropboxusercontent.com (uc470df8ee8261c87e0c35713cd1.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc470df8ee8261c87e0c35713cd1.dl.dropboxusercontent.com (uc470df8ee8261c87e0c35713cd1.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197683526 (189M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 188.53M  9.99MB/s    in 37s
#
# 2023-10-13 11:34:31 (5.03 MB/s) - ‘data.zip’ saved [197683526/197683526]

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
# !unzip -q data.zip
# Out:
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed

# %%
# !tree -d ./cat-dog-panda
# Out:
# ./cat-dog-panda
# ├── training
# │   ├── cat
# │   ├── dog
# │   └── panda
# └── validation
#     ├── cat
#     ├── dog
#     └── panda
#
# 8 directories

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation</font><a name="step3"></a>
# Already covered in the previous notebook.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %%
def image_augmented_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(0.1),
        transforms.RandomAutocontrast(0.1),
        transforms.RandomAdjustSharpness(2,0.1),
        #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.RandomRotation(20)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)
    
    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)
    
    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i] 
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]
    
    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)
    
    # var[X] = E[X**2] - E[X]**2
    
    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2
    
    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)
        
    std = var ** 0.5
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
# Data loader for generating batches of data to be used by the training routine

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:green">3.4. Prepare Data</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')
    test_data_path = os.path.join(data_root, 'validation')    
    
    mean, std = get_mean_std(train_data_path, num_workers)
    
    
    if data_augmentation:
        train_transformers = image_augmented_transforms(mean, std)
    else:
        train_transformers = image_common_transforms(mean, std)
    
    test_transformers = image_common_transforms(mean, std)
    
    
    train_dataset = datasets.ImageFolder(train_data_path, transform=train_transformers)  # dataset de treino
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, num_workers=num_workers)  # data loader de treino
    
    
    test_dataset = datasets.ImageFolder(test_data_path, transform=test_transformers)  # dataset de teste
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=False, num_workers=num_workers)  # data loader de teste
    
    
    return train_dataloader, test_dataloader

# %% [markdown]
# # <font style="color:blue">Step 4: Train Your Model</font><a name="step4"></a>
#
# Now, create the training pipeline, and train your model on the full data.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [20 Points]</font>
#
# To achieve good results, change the parameters given in these configurations. Score 20 points for all right choices.

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>
#
# Fix the seed (e.g., `21`) to get a reproducible result.

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 16 
    epochs_count: int = 250
    init_learning_rate: float = 0.0005  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You are already familiar with the training function. No changes needed here.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        with torch.no_grad():
            output = model(data)
        
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Note: Before calling the train function, we calculate the validation loss, which we know should be close to $\log(\text{num_classes})$. Also, the accuracy should be close to $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available() and train_config.device == 'cuda':
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    print('treino: ', len(train_loader.dataset))    
    print('teste: ', len(test_loader.dataset))

    
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
        # scheduler step/ update learning rate
        if scheduler is not None:
            scheduler.step()        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:red">4.8. Define Model [20 Points]</font>
#
# Next, define the CNN model. Keep iterating. Do this by training various models. Just ,change the :
#
# - number of layers
# - parameters inside the layers
# - different types of layers

# %%
class MyModel(nn.Module):

    def __init__(self):
        super(MyModel, self).__init__()
        
        self._body = nn.Sequential(
            # input = 3 x 224 x 224
            nn.Conv2d(3, 16, 3, padding='same'),
            nn.BatchNorm2d(16),
            nn.ReLU(True),            
            # input = 16 x 224 x 224
            nn.Conv2d(16, 24, 3, padding='same'),
            nn.BatchNorm2d(24),
            nn.ReLU(True),
            nn.MaxPool2d(2),            
            nn.Dropout(0.2),
            # input = 32 x 112 x 112
            nn.Conv2d(24, 32, 3, padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Dropout(0.3),

        )
        
      
        self._classifier = nn.Sequential(
            nn.Linear(32*56*56, 200),
            nn.ReLU(True),
            nn.Dropout(0.5),
            
            nn.Linear(200, 64),            
            nn.ReLU(True),
            nn.Dropout(0.4),
            
            nn.Linear(64, 3)
        )


    
    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._classifier(x)
        return x

# %% [markdown]
# ## <font style="color:red">4.9. Training [20 Points]</font>
#
# Experiment with:
#
# - Optimizers and learning rate schedulers \[You can  get good results even without a learning rate scheduler\]
#
# - Regularization techniques like Data Augmentation, Dropout, BatchNorm

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()



# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)


### CHANGE HERE ###
decay_rate: float = 0.051
lmbda = lambda epoch: 1/(1 + decay_rate * epoch)
# Scheduler
scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lmbda)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(16, 24, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Dropout(p=0.3, inplace=False)
#   )
#   (_classifier): Sequential(
#     (0): Linear(in_features=100352, out_features=200, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=200, out_features=64, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=scheduler, data_augmentation=True)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
# treino:  2400
# teste:  600
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Initial Test Loss : 1.098692,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 1.759836 Acc: 0.3958
# Elapsed 16.83s, 16.83 s/epoch, 0.11 s/batch, ets 4190.26s
#
# Test set: Average loss: 1.0083, Accuracy: 362/600 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 1.039288 Acc: 0.4508
# Elapsed 37.63s, 18.81 s/epoch, 0.13 s/batch, ets 4666.00s
#
# Test set: Average loss: 0.9084, Accuracy: 335/600 (56%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 1.008566 Acc: 0.4612
# Elapsed 57.70s, 19.23 s/epoch, 0.13 s/batch, ets 4750.74s
#
# Test set: Average loss: 0.8550, Accuracy: 336/600 (56%)
#
# Model Improved. Saving the Model...
#
# Epoch: 3
# Train Loss: 0.985216 Acc: 0.4879
# Elapsed 78.52s, 19.63 s/epoch, 0.13 s/batch, ets 4828.72s
#
# Test set: Average loss: 0.8412, Accuracy: 363/600 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 4
# Train Loss: 0.971750 Acc: 0.4829
# Elapsed 99.54s, 19.91 s/epoch, 0.13 s/batch, ets 4877.30s
#
# Test set: Average loss: 0.8408, Accuracy: 354/600 (59%)
#
# Model Improved. Saving the Model...
#
# Epoch: 5
# Train Loss: 0.966276 Acc: 0.4908
# Elapsed 119.38s, 19.90 s/epoch, 0.13 s/batch, ets 4854.93s
#
# Test set: Average loss: 0.8192, Accuracy: 368/600 (61%)
#
# Model Improved. Saving the Model...
#
# Epoch: 6
# Train Loss: 0.902426 Acc: 0.5317
# Elapsed 140.47s, 20.07 s/epoch, 0.13 s/batch, ets 4876.40s
#
# Test set: Average loss: 0.7372, Accuracy: 401/600 (67%)
#
# Model Improved. Saving the Model...
#
# Epoch: 7
# Train Loss: 0.909934 Acc: 0.5154
# Elapsed 161.14s, 20.14 s/epoch, 0.13 s/batch, ets 4874.48s
#
# Test set: Average loss: 0.7565, Accuracy: 384/600 (64%)
#
# Epoch: 8
# Train Loss: 0.866403 Acc: 0.5296
# Elapsed 180.55s, 20.06 s/epoch, 0.13 s/batch, ets 4834.76s
#
# Test set: Average loss: 0.7629, Accuracy: 358/600 (60%)
#
# Epoch: 9
# Train Loss: 0.854820 Acc: 0.5233
# Elapsed 201.11s, 20.11 s/epoch, 0.13 s/batch, ets 4826.68s
#
# Test set: Average loss: 0.7113, Accuracy: 377/600 (63%)
#
# Model Improved. Saving the Model...
#
# Epoch: 10
# Train Loss: 0.810109 Acc: 0.5437
# Elapsed 221.84s, 20.17 s/epoch, 0.13 s/batch, ets 4819.96s
#
# Test set: Average loss: 0.6823, Accuracy: 396/600 (66%)
#
# Model Improved. Saving the Model...
#
# Epoch: 11
# Train Loss: 0.802632 Acc: 0.5537
# Elapsed 241.88s, 20.16 s/epoch, 0.13 s/batch, ets 4797.36s
#
# Test set: Average loss: 0.6376, Accuracy: 410/600 (68%)
#
# Model Improved. Saving the Model...
#
# Epoch: 12
# Train Loss: 0.822702 Acc: 0.5404
# Elapsed 262.57s, 20.20 s/epoch, 0.13 s/batch, ets 4786.94s
#
# Test set: Average loss: 0.6899, Accuracy: 375/600 (62%)
#
# Epoch: 13
# Train Loss: 0.780849 Acc: 0.5454
# Elapsed 282.25s, 20.16 s/epoch, 0.13 s/batch, ets 4757.98s
#
# Test set: Average loss: 0.6348, Accuracy: 420/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 14
# Train Loss: 0.789366 Acc: 0.5442
# Elapsed 303.31s, 20.22 s/epoch, 0.13 s/batch, ets 4751.80s
#
# Test set: Average loss: 0.6488, Accuracy: 409/600 (68%)
#
# Epoch: 15
# Train Loss: 0.780036 Acc: 0.5775
# Elapsed 323.90s, 20.24 s/epoch, 0.13 s/batch, ets 4737.08s
#
# Test set: Average loss: 0.6834, Accuracy: 387/600 (64%)
#
# Epoch: 16
# Train Loss: 0.776982 Acc: 0.5933
# Elapsed 343.62s, 20.21 s/epoch, 0.13 s/batch, ets 4709.63s
#
# Test set: Average loss: 0.6414, Accuracy: 390/600 (65%)
#
# Epoch: 17
# Train Loss: 0.763417 Acc: 0.6042
# Elapsed 364.26s, 20.24 s/epoch, 0.13 s/batch, ets 4694.93s
#
# Test set: Average loss: 0.6739, Accuracy: 391/600 (65%)
#
# Epoch: 18
# Train Loss: 0.757788 Acc: 0.5942
# Elapsed 384.76s, 20.25 s/epoch, 0.14 s/batch, ets 4677.85s
#
# Test set: Average loss: 0.6407, Accuracy: 406/600 (68%)
#
# Epoch: 19
# Train Loss: 0.743050 Acc: 0.5992
# Elapsed 404.54s, 20.23 s/epoch, 0.13 s/batch, ets 4652.26s
#
# Test set: Average loss: 0.6767, Accuracy: 377/600 (63%)
#
# Epoch: 20
# Train Loss: 0.745610 Acc: 0.5942
# Elapsed 425.16s, 20.25 s/epoch, 0.13 s/batch, ets 4636.32s
#
# Test set: Average loss: 0.6228, Accuracy: 405/600 (68%)
#
# Model Improved. Saving the Model...
#
# Epoch: 21
# Train Loss: 0.754369 Acc: 0.6058
# Elapsed 446.08s, 20.28 s/epoch, 0.14 s/batch, ets 4622.99s
#
# Test set: Average loss: 0.6483, Accuracy: 404/600 (67%)
#
# Epoch: 22
# Train Loss: 0.756080 Acc: 0.6025
# Elapsed 465.80s, 20.25 s/epoch, 0.14 s/batch, ets 4597.23s
#
# Test set: Average loss: 0.6863, Accuracy: 394/600 (66%)
#
# Epoch: 23
# Train Loss: 0.738762 Acc: 0.6258
# Elapsed 486.05s, 20.25 s/epoch, 0.14 s/batch, ets 4576.95s
#
# Test set: Average loss: 0.6320, Accuracy: 417/600 (70%)
#
# Epoch: 24
# Train Loss: 0.737382 Acc: 0.6229
# Elapsed 505.84s, 20.23 s/epoch, 0.13 s/batch, ets 4552.54s
#
# Test set: Average loss: 0.6015, Accuracy: 433/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 25
# Train Loss: 0.757681 Acc: 0.5971
# Elapsed 526.71s, 20.26 s/epoch, 0.14 s/batch, ets 4537.82s
#
# Test set: Average loss: 0.6217, Accuracy: 441/600 (74%)
#
# Epoch: 26
# Train Loss: 0.729953 Acc: 0.6038
# Elapsed 547.34s, 20.27 s/epoch, 0.14 s/batch, ets 4520.59s
#
# Test set: Average loss: 0.6107, Accuracy: 415/600 (69%)
#
# Epoch: 27
# Train Loss: 0.729974 Acc: 0.6233
# Elapsed 566.99s, 20.25 s/epoch, 0.13 s/batch, ets 4495.38s
#
# Test set: Average loss: 0.6079, Accuracy: 413/600 (69%)
#
# Epoch: 28
# Train Loss: 0.728886 Acc: 0.6242
# Elapsed 587.15s, 20.25 s/epoch, 0.13 s/batch, ets 4474.47s
#
# Test set: Average loss: 0.6267, Accuracy: 406/600 (68%)
#
# Epoch: 29
# Train Loss: 0.718583 Acc: 0.6258
# Elapsed 607.35s, 20.25 s/epoch, 0.13 s/batch, ets 4453.92s
#
# Test set: Average loss: 0.6264, Accuracy: 434/600 (72%)
#
# Epoch: 30
# Train Loss: 0.721870 Acc: 0.6179
# Elapsed 626.98s, 20.23 s/epoch, 0.13 s/batch, ets 4429.34s
#
# Test set: Average loss: 0.6443, Accuracy: 430/600 (72%)
#
# Epoch: 31
# Train Loss: 0.746862 Acc: 0.6146
# Elapsed 647.20s, 20.23 s/epoch, 0.13 s/batch, ets 4409.07s
#
# Test set: Average loss: 0.6331, Accuracy: 425/600 (71%)
#
# Epoch: 32
# Train Loss: 0.718247 Acc: 0.6188
# Elapsed 667.29s, 20.22 s/epoch, 0.13 s/batch, ets 4387.93s
#
# Test set: Average loss: 0.6223, Accuracy: 415/600 (69%)
#
# Epoch: 33
# Train Loss: 0.702925 Acc: 0.6192
# Elapsed 687.05s, 20.21 s/epoch, 0.13 s/batch, ets 4364.78s
#
# Test set: Average loss: 0.6631, Accuracy: 408/600 (68%)
#
# Epoch: 34
# Train Loss: 0.724456 Acc: 0.6154
# Elapsed 707.65s, 20.22 s/epoch, 0.13 s/batch, ets 4347.01s
#
# Test set: Average loss: 0.6047, Accuracy: 391/600 (65%)
#
# Epoch: 35
# Train Loss: 0.716120 Acc: 0.6033
# Elapsed 727.56s, 20.21 s/epoch, 0.13 s/batch, ets 4324.94s
#
# Test set: Average loss: 0.6183, Accuracy: 422/600 (70%)
#
# Epoch: 36
# Train Loss: 0.711223 Acc: 0.6171
# Elapsed 748.15s, 20.22 s/epoch, 0.13 s/batch, ets 4306.94s
#
# Test set: Average loss: 0.6289, Accuracy: 415/600 (69%)
#
# Epoch: 37
# Train Loss: 0.700828 Acc: 0.6246
# Elapsed 768.99s, 20.24 s/epoch, 0.13 s/batch, ets 4290.16s
#
# Test set: Average loss: 0.5985, Accuracy: 422/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 38
# Train Loss: 0.709413 Acc: 0.6171
# Elapsed 789.57s, 20.25 s/epoch, 0.13 s/batch, ets 4271.80s
#
# Test set: Average loss: 0.6024, Accuracy: 440/600 (73%)
#
# Epoch: 39
# Train Loss: 0.710981 Acc: 0.6025
# Elapsed 810.02s, 20.25 s/epoch, 0.14 s/batch, ets 4252.60s
#
# Test set: Average loss: 0.6150, Accuracy: 425/600 (71%)
#
# Epoch: 40
# Train Loss: 0.706630 Acc: 0.6138
# Elapsed 830.26s, 20.25 s/epoch, 0.14 s/batch, ets 4232.32s
#
# Test set: Average loss: 0.6074, Accuracy: 438/600 (73%)
#
# Epoch: 41
# Train Loss: 0.722914 Acc: 0.5971
# Elapsed 849.99s, 20.24 s/epoch, 0.13 s/batch, ets 4209.45s
#
# Test set: Average loss: 0.6038, Accuracy: 415/600 (69%)
#
# Epoch: 42
# Train Loss: 0.699424 Acc: 0.6204
# Elapsed 870.38s, 20.24 s/epoch, 0.13 s/batch, ets 4189.99s
#
# Test set: Average loss: 0.6067, Accuracy: 424/600 (71%)
#
# Epoch: 43
# Train Loss: 0.698734 Acc: 0.6296
# Elapsed 890.57s, 20.24 s/epoch, 0.13 s/batch, ets 4169.51s
#
# Test set: Average loss: 0.6321, Accuracy: 426/600 (71%)
#
# Epoch: 44
# Train Loss: 0.706186 Acc: 0.6200
# Elapsed 910.70s, 20.24 s/epoch, 0.13 s/batch, ets 4148.75s
#
# Test set: Average loss: 0.6066, Accuracy: 431/600 (72%)
#
# Epoch: 45
# Train Loss: 0.678423 Acc: 0.6342
# Elapsed 931.01s, 20.24 s/epoch, 0.13 s/batch, ets 4128.82s
#
# Test set: Average loss: 0.6105, Accuracy: 433/600 (72%)
#
# Epoch: 46
# Train Loss: 0.684880 Acc: 0.6304
# Elapsed 951.01s, 20.23 s/epoch, 0.13 s/batch, ets 4107.55s
#
# Test set: Average loss: 0.6013, Accuracy: 437/600 (73%)
#
# Epoch: 47
# Train Loss: 0.702333 Acc: 0.6208
# Elapsed 971.86s, 20.25 s/epoch, 0.13 s/batch, ets 4089.93s
#
# Test set: Average loss: 0.6192, Accuracy: 435/600 (72%)
#
# Epoch: 48
# Train Loss: 0.688808 Acc: 0.6467
# Elapsed 992.95s, 20.26 s/epoch, 0.14 s/batch, ets 4073.13s
#
# Test set: Average loss: 0.5979, Accuracy: 433/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 49
# Train Loss: 0.700911 Acc: 0.6229
# Elapsed 1013.87s, 20.28 s/epoch, 0.14 s/batch, ets 4055.48s
#
# Test set: Average loss: 0.6189, Accuracy: 438/600 (73%)
#
# Epoch: 50
# Train Loss: 0.695609 Acc: 0.6271
# Elapsed 1034.51s, 20.28 s/epoch, 0.14 s/batch, ets 4036.63s
#
# Test set: Average loss: 0.6068, Accuracy: 429/600 (72%)
#
# Epoch: 51
# Train Loss: 0.692988 Acc: 0.6338
# Elapsed 1055.20s, 20.29 s/epoch, 0.14 s/batch, ets 4017.89s
#
# Test set: Average loss: 0.6167, Accuracy: 427/600 (71%)
#
# Epoch: 52
# Train Loss: 0.694322 Acc: 0.6412
# Elapsed 1075.45s, 20.29 s/epoch, 0.14 s/batch, ets 3997.44s
#
# Test set: Average loss: 0.5933, Accuracy: 425/600 (71%)
#
# Model Improved. Saving the Model...
#
# Epoch: 53
# Train Loss: 0.688088 Acc: 0.6296
# Elapsed 1096.49s, 20.31 s/epoch, 0.14 s/batch, ets 3979.85s
#
# Test set: Average loss: 0.6001, Accuracy: 432/600 (72%)
#
# Epoch: 54
# Train Loss: 0.673680 Acc: 0.6354
# Elapsed 1116.95s, 20.31 s/epoch, 0.14 s/batch, ets 3960.11s
#
# Test set: Average loss: 0.6469, Accuracy: 397/600 (66%)
#
# Epoch: 55
# Train Loss: 0.692818 Acc: 0.6246
# Elapsed 1136.47s, 20.29 s/epoch, 0.14 s/batch, ets 3937.07s
#
# Test set: Average loss: 0.6347, Accuracy: 396/600 (66%)
#
# Epoch: 56
# Train Loss: 0.681887 Acc: 0.6408
# Elapsed 1157.03s, 20.30 s/epoch, 0.14 s/batch, ets 3917.66s
#
# Test set: Average loss: 0.5868, Accuracy: 439/600 (73%)
#
# Model Improved. Saving the Model...
#
# Epoch: 57
# Train Loss: 0.678899 Acc: 0.6288
# Elapsed 1177.64s, 20.30 s/epoch, 0.14 s/batch, ets 3898.40s
#
# Test set: Average loss: 0.5922, Accuracy: 449/600 (75%)
#
# Epoch: 58
# Train Loss: 0.672456 Acc: 0.6438
# Elapsed 1197.45s, 20.30 s/epoch, 0.14 s/batch, ets 3876.47s
#
# Test set: Average loss: 0.5840, Accuracy: 450/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 59
# Train Loss: 0.683000 Acc: 0.6379
# Elapsed 1218.56s, 20.31 s/epoch, 0.14 s/batch, ets 3858.76s
#
# Test set: Average loss: 0.5928, Accuracy: 447/600 (74%)
#
# Epoch: 60
# Train Loss: 0.657611 Acc: 0.6417
# Elapsed 1238.32s, 20.30 s/epoch, 0.14 s/batch, ets 3836.77s
#
# Test set: Average loss: 0.6095, Accuracy: 400/600 (67%)
#
# Epoch: 61
# Train Loss: 0.672974 Acc: 0.6404
# Elapsed 1258.59s, 20.30 s/epoch, 0.14 s/batch, ets 3816.36s
#
# Test set: Average loss: 0.5921, Accuracy: 426/600 (71%)
#
# Epoch: 62
# Train Loss: 0.676952 Acc: 0.6512
# Elapsed 1279.27s, 20.31 s/epoch, 0.14 s/batch, ets 3797.21s
#
# Test set: Average loss: 0.5786, Accuracy: 436/600 (73%)
#
# Model Improved. Saving the Model...
#
# Epoch: 63
# Train Loss: 0.679397 Acc: 0.6342
# Elapsed 1299.28s, 20.30 s/epoch, 0.14 s/batch, ets 3776.04s
#
# Test set: Average loss: 0.6064, Accuracy: 421/600 (70%)
#
# Epoch: 64
# Train Loss: 0.677025 Acc: 0.6433
# Elapsed 1320.19s, 20.31 s/epoch, 0.14 s/batch, ets 3757.47s
#
# Test set: Average loss: 0.5929, Accuracy: 438/600 (73%)
#
# Epoch: 65
# Train Loss: 0.653342 Acc: 0.6571
# Elapsed 1341.13s, 20.32 s/epoch, 0.14 s/batch, ets 3738.90s
#
# Test set: Average loss: 0.5930, Accuracy: 447/600 (74%)
#
# Epoch: 66
# Train Loss: 0.672670 Acc: 0.6396
# Elapsed 1360.98s, 20.31 s/epoch, 0.14 s/batch, ets 3717.30s
#
# Test set: Average loss: 0.5848, Accuracy: 449/600 (75%)
#
# Epoch: 67
# Train Loss: 0.666323 Acc: 0.6479
# Elapsed 1381.64s, 20.32 s/epoch, 0.14 s/batch, ets 3697.91s
#
# Test set: Average loss: 0.5884, Accuracy: 444/600 (74%)
#
# Epoch: 68
# Train Loss: 0.676342 Acc: 0.6383
# Elapsed 1402.40s, 20.32 s/epoch, 0.14 s/batch, ets 3678.77s
#
# Test set: Average loss: 0.5842, Accuracy: 457/600 (76%)
#
# Epoch: 69
# Train Loss: 0.655390 Acc: 0.6675
# Elapsed 1422.12s, 20.32 s/epoch, 0.14 s/batch, ets 3656.87s
#
# Test set: Average loss: 0.5843, Accuracy: 455/600 (76%)
#
# Epoch: 70
# Train Loss: 0.662258 Acc: 0.6479
# Elapsed 1443.00s, 20.32 s/epoch, 0.14 s/batch, ets 3637.98s
#
# Test set: Average loss: 0.5952, Accuracy: 416/600 (69%)
#
# Epoch: 71
# Train Loss: 0.654718 Acc: 0.6550
# Elapsed 1462.49s, 20.31 s/epoch, 0.14 s/batch, ets 3615.60s
#
# Test set: Average loss: 0.5690, Accuracy: 449/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 72
# Train Loss: 0.664381 Acc: 0.6446
# Elapsed 1483.21s, 20.32 s/epoch, 0.14 s/batch, ets 3596.27s
#
# Test set: Average loss: 0.5793, Accuracy: 443/600 (74%)
#
# Epoch: 73
# Train Loss: 0.668531 Acc: 0.6642
# Elapsed 1503.50s, 20.32 s/epoch, 0.14 s/batch, ets 3575.89s
#
# Test set: Average loss: 0.5814, Accuracy: 443/600 (74%)
#
# Epoch: 74
# Train Loss: 0.653019 Acc: 0.6650
# Elapsed 1523.11s, 20.31 s/epoch, 0.14 s/batch, ets 3553.93s
#
# Test set: Average loss: 0.5722, Accuracy: 445/600 (74%)
#
# Epoch: 75
# Train Loss: 0.673132 Acc: 0.6521
# Elapsed 1543.76s, 20.31 s/epoch, 0.14 s/batch, ets 3534.40s
#
# Test set: Average loss: 0.5555, Accuracy: 450/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 76
# Train Loss: 0.655619 Acc: 0.6400
# Elapsed 1564.44s, 20.32 s/epoch, 0.14 s/batch, ets 3514.90s
#
# Test set: Average loss: 0.6047, Accuracy: 438/600 (73%)
#
# Epoch: 77
# Train Loss: 0.666901 Acc: 0.6479
# Elapsed 1584.12s, 20.31 s/epoch, 0.14 s/batch, ets 3493.18s
#
# Test set: Average loss: 0.5787, Accuracy: 452/600 (75%)
#
# Epoch: 78
# Train Loss: 0.661069 Acc: 0.6496
# Elapsed 1604.90s, 20.32 s/epoch, 0.14 s/batch, ets 3473.91s
#
# Test set: Average loss: 0.5904, Accuracy: 448/600 (75%)
#
# Epoch: 79
# Train Loss: 0.682148 Acc: 0.6375
# Elapsed 1625.94s, 20.32 s/epoch, 0.14 s/batch, ets 3455.13s
#
# Test set: Average loss: 0.5671, Accuracy: 448/600 (75%)
#
# Epoch: 80
# Train Loss: 0.655462 Acc: 0.6533
# Elapsed 1646.31s, 20.32 s/epoch, 0.14 s/batch, ets 3434.90s
#
# Test set: Average loss: 0.5729, Accuracy: 432/600 (72%)
#
# Epoch: 81
# Train Loss: 0.658011 Acc: 0.6383
# Elapsed 1667.42s, 20.33 s/epoch, 0.14 s/batch, ets 3416.17s
#
# Test set: Average loss: 0.6074, Accuracy: 440/600 (73%)
#
# Epoch: 82
# Train Loss: 0.668712 Acc: 0.6525
# Elapsed 1687.98s, 20.34 s/epoch, 0.14 s/batch, ets 3396.31s
#
# Test set: Average loss: 0.5574, Accuracy: 456/600 (76%)
#
# Epoch: 83
# Train Loss: 0.676120 Acc: 0.6404
# Elapsed 1708.29s, 20.34 s/epoch, 0.14 s/batch, ets 3375.91s
#
# Test set: Average loss: 0.5900, Accuracy: 441/600 (74%)
#
# Epoch: 84
# Train Loss: 0.644777 Acc: 0.6479
# Elapsed 1729.06s, 20.34 s/epoch, 0.14 s/batch, ets 3356.41s
#
# Test set: Average loss: 0.5540, Accuracy: 454/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 85
# Train Loss: 0.656473 Acc: 0.6550
# Elapsed 1748.84s, 20.34 s/epoch, 0.14 s/batch, ets 3335.00s
#
# Test set: Average loss: 0.5724, Accuracy: 459/600 (76%)
#
# Epoch: 86
# Train Loss: 0.644580 Acc: 0.6604
# Elapsed 1769.19s, 20.34 s/epoch, 0.14 s/batch, ets 3314.68s
#
# Test set: Average loss: 0.5678, Accuracy: 453/600 (76%)
#
# Epoch: 87
# Train Loss: 0.645711 Acc: 0.6562
# Elapsed 1789.34s, 20.33 s/epoch, 0.14 s/batch, ets 3294.02s
#
# Test set: Average loss: 0.5660, Accuracy: 451/600 (75%)
#
# Epoch: 88
# Train Loss: 0.655869 Acc: 0.6529
# Elapsed 1808.94s, 20.33 s/epoch, 0.14 s/batch, ets 3272.36s
#
# Test set: Average loss: 0.5609, Accuracy: 457/600 (76%)
#
# Epoch: 89
# Train Loss: 0.643552 Acc: 0.6567
# Elapsed 1829.15s, 20.32 s/epoch, 0.14 s/batch, ets 3251.82s
#
# Test set: Average loss: 0.5605, Accuracy: 455/600 (76%)
#
# Epoch: 90
# Train Loss: 0.648664 Acc: 0.6708
# Elapsed 1849.51s, 20.32 s/epoch, 0.14 s/batch, ets 3231.56s
#
# Test set: Average loss: 0.5541, Accuracy: 458/600 (76%)
#
# Epoch: 91
# Train Loss: 0.659639 Acc: 0.6400
# Elapsed 1868.93s, 20.31 s/epoch, 0.14 s/batch, ets 3209.69s
#
# Test set: Average loss: 0.5762, Accuracy: 448/600 (75%)
#
# Epoch: 92
# Train Loss: 0.643715 Acc: 0.6579
# Elapsed 1889.14s, 20.31 s/epoch, 0.14 s/batch, ets 3189.20s
#
# Test set: Average loss: 0.5694, Accuracy: 452/600 (75%)
#
# Epoch: 93
# Train Loss: 0.637862 Acc: 0.6708
# Elapsed 1908.78s, 20.31 s/epoch, 0.14 s/batch, ets 3167.76s
#
# Test set: Average loss: 0.5538, Accuracy: 452/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 94
# Train Loss: 0.655197 Acc: 0.6625
# Elapsed 1929.59s, 20.31 s/epoch, 0.14 s/batch, ets 3148.27s
#
# Test set: Average loss: 0.5667, Accuracy: 455/600 (76%)
#
# Epoch: 95
# Train Loss: 0.654262 Acc: 0.6417
# Elapsed 1950.00s, 20.31 s/epoch, 0.14 s/batch, ets 3128.13s
#
# Test set: Average loss: 0.5541, Accuracy: 453/600 (76%)
#
# Epoch: 96
# Train Loss: 0.654565 Acc: 0.6500
# Elapsed 1969.40s, 20.30 s/epoch, 0.14 s/batch, ets 3106.37s
#
# Test set: Average loss: 0.5906, Accuracy: 437/600 (73%)
#
# Epoch: 97
# Train Loss: 0.658207 Acc: 0.6579
# Elapsed 1989.35s, 20.30 s/epoch, 0.14 s/batch, ets 3085.52s
#
# Test set: Average loss: 0.5566, Accuracy: 457/600 (76%)
#
# Epoch: 98
# Train Loss: 0.649903 Acc: 0.6746
# Elapsed 2009.55s, 20.30 s/epoch, 0.14 s/batch, ets 3065.07s
#
# Test set: Average loss: 0.5536, Accuracy: 448/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 99
# Train Loss: 0.657046 Acc: 0.6604
# Elapsed 2029.64s, 20.30 s/epoch, 0.14 s/batch, ets 3044.47s
#
# Test set: Average loss: 0.5581, Accuracy: 461/600 (77%)
#
# Epoch: 100
# Train Loss: 0.649847 Acc: 0.6558
# Elapsed 2049.99s, 20.30 s/epoch, 0.14 s/batch, ets 3024.24s
#
# Test set: Average loss: 0.5587, Accuracy: 459/600 (76%)
#
# Epoch: 101
# Train Loss: 0.654081 Acc: 0.6542
# Elapsed 2070.05s, 20.29 s/epoch, 0.14 s/batch, ets 3003.60s
#
# Test set: Average loss: 0.5737, Accuracy: 447/600 (74%)
#
# Epoch: 102
# Train Loss: 0.649976 Acc: 0.6746
# Elapsed 2089.82s, 20.29 s/epoch, 0.14 s/batch, ets 2982.56s
#
# Test set: Average loss: 0.5550, Accuracy: 463/600 (77%)
#
# Epoch: 103
# Train Loss: 0.644304 Acc: 0.6538
# Elapsed 2110.01s, 20.29 s/epoch, 0.14 s/batch, ets 2962.12s
#
# Test set: Average loss: 0.5761, Accuracy: 445/600 (74%)
#
# Epoch: 104
# Train Loss: 0.647516 Acc: 0.6671
# Elapsed 2129.48s, 20.28 s/epoch, 0.14 s/batch, ets 2940.71s
#
# Test set: Average loss: 0.5651, Accuracy: 457/600 (76%)
#
# Epoch: 105
# Train Loss: 0.648812 Acc: 0.6613
# Elapsed 2149.65s, 20.28 s/epoch, 0.14 s/batch, ets 2920.28s
#
# Test set: Average loss: 0.5536, Accuracy: 451/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 106
# Train Loss: 0.653535 Acc: 0.6533
# Elapsed 2170.37s, 20.28 s/epoch, 0.14 s/batch, ets 2900.58s
#
# Test set: Average loss: 0.5663, Accuracy: 446/600 (74%)
#
# Epoch: 107
# Train Loss: 0.644734 Acc: 0.6567
# Elapsed 2189.87s, 20.28 s/epoch, 0.14 s/batch, ets 2879.27s
#
# Test set: Average loss: 0.5627, Accuracy: 439/600 (73%)
#
# Epoch: 108
# Train Loss: 0.627303 Acc: 0.6825
# Elapsed 2210.19s, 20.28 s/epoch, 0.14 s/batch, ets 2859.05s
#
# Test set: Average loss: 0.5753, Accuracy: 452/600 (75%)
#
# Epoch: 109
# Train Loss: 0.646433 Acc: 0.6613
# Elapsed 2230.46s, 20.28 s/epoch, 0.14 s/batch, ets 2838.77s
#
# Test set: Average loss: 0.5529, Accuracy: 463/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 110
# Train Loss: 0.633962 Acc: 0.6554
# Elapsed 2250.47s, 20.27 s/epoch, 0.14 s/batch, ets 2818.16s
#
# Test set: Average loss: 0.5571, Accuracy: 461/600 (77%)
#
# Epoch: 111
# Train Loss: 0.635865 Acc: 0.6625
# Elapsed 2270.47s, 20.27 s/epoch, 0.14 s/batch, ets 2797.55s
#
# Test set: Average loss: 0.5652, Accuracy: 448/600 (75%)
#
# Epoch: 112
# Train Loss: 0.652796 Acc: 0.6579
# Elapsed 2290.63s, 20.27 s/epoch, 0.14 s/batch, ets 2777.13s
#
# Test set: Average loss: 0.5488, Accuracy: 460/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 113
# Train Loss: 0.638489 Acc: 0.6687
# Elapsed 2312.27s, 20.28 s/epoch, 0.14 s/batch, ets 2758.49s
#
# Test set: Average loss: 0.5443, Accuracy: 468/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 114
# Train Loss: 0.639313 Acc: 0.6717
# Elapsed 2333.37s, 20.29 s/epoch, 0.14 s/batch, ets 2739.18s
#
# Test set: Average loss: 0.5819, Accuracy: 436/600 (73%)
#
# Epoch: 115
# Train Loss: 0.642521 Acc: 0.6654
# Elapsed 2353.13s, 20.29 s/epoch, 0.14 s/batch, ets 2718.27s
#
# Test set: Average loss: 0.5457, Accuracy: 458/600 (76%)
#
# Epoch: 116
# Train Loss: 0.630836 Acc: 0.6792
# Elapsed 2373.61s, 20.29 s/epoch, 0.14 s/batch, ets 2698.20s
#
# Test set: Average loss: 0.5637, Accuracy: 453/600 (76%)
#
# Epoch: 117
# Train Loss: 0.629753 Acc: 0.6708
# Elapsed 2394.41s, 20.29 s/epoch, 0.14 s/batch, ets 2678.50s
#
# Test set: Average loss: 0.5454, Accuracy: 464/600 (77%)
#
# Epoch: 118
# Train Loss: 0.637393 Acc: 0.6546
# Elapsed 2414.17s, 20.29 s/epoch, 0.14 s/batch, ets 2657.62s
#
# Test set: Average loss: 0.5612, Accuracy: 457/600 (76%)
#
# Epoch: 119
# Train Loss: 0.620970 Acc: 0.6742
# Elapsed 2434.36s, 20.29 s/epoch, 0.14 s/batch, ets 2637.23s
#
# Test set: Average loss: 0.5332, Accuracy: 469/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 120
# Train Loss: 0.636599 Acc: 0.6587
# Elapsed 2454.93s, 20.29 s/epoch, 0.14 s/batch, ets 2617.24s
#
# Test set: Average loss: 0.5488, Accuracy: 465/600 (78%)
#
# Epoch: 121
# Train Loss: 0.641070 Acc: 0.6696
# Elapsed 2474.28s, 20.28 s/epoch, 0.14 s/batch, ets 2595.97s
#
# Test set: Average loss: 0.5601, Accuracy: 440/600 (73%)
#
# Epoch: 122
# Train Loss: 0.630273 Acc: 0.6567
# Elapsed 2494.47s, 20.28 s/epoch, 0.14 s/batch, ets 2575.59s
#
# Test set: Average loss: 0.5445, Accuracy: 465/600 (78%)
#
# Epoch: 123
# Train Loss: 0.622653 Acc: 0.6842
# Elapsed 2513.69s, 20.27 s/epoch, 0.14 s/batch, ets 2554.23s
#
# Test set: Average loss: 0.5425, Accuracy: 464/600 (77%)
#
# Epoch: 124
# Train Loss: 0.639682 Acc: 0.6687
# Elapsed 2533.92s, 20.27 s/epoch, 0.14 s/batch, ets 2533.92s
#
# Test set: Average loss: 0.5541, Accuracy: 459/600 (76%)
#
# Epoch: 125
# Train Loss: 0.631220 Acc: 0.6717
# Elapsed 2554.12s, 20.27 s/epoch, 0.14 s/batch, ets 2513.58s
#
# Test set: Average loss: 0.5717, Accuracy: 440/600 (73%)
#
# Epoch: 126
# Train Loss: 0.634180 Acc: 0.6796
# Elapsed 2573.72s, 20.27 s/epoch, 0.14 s/batch, ets 2492.66s
#
# Test set: Average loss: 0.5404, Accuracy: 456/600 (76%)
#
# Epoch: 127
# Train Loss: 0.633438 Acc: 0.6825
# Elapsed 2594.09s, 20.27 s/epoch, 0.14 s/batch, ets 2472.49s
#
# Test set: Average loss: 0.5452, Accuracy: 456/600 (76%)
#
# Epoch: 128
# Train Loss: 0.612202 Acc: 0.6929
# Elapsed 2614.25s, 20.27 s/epoch, 0.14 s/batch, ets 2452.13s
#
# Test set: Average loss: 0.5381, Accuracy: 466/600 (78%)
#
# Epoch: 129
# Train Loss: 0.636704 Acc: 0.6817
# Elapsed 2633.88s, 20.26 s/epoch, 0.14 s/batch, ets 2431.28s
#
# Test set: Average loss: 0.5404, Accuracy: 467/600 (78%)
#
# Epoch: 130
# Train Loss: 0.626242 Acc: 0.6775
# Elapsed 2654.15s, 20.26 s/epoch, 0.14 s/batch, ets 2411.02s
#
# Test set: Average loss: 0.5341, Accuracy: 459/600 (76%)
#
# Epoch: 131
# Train Loss: 0.651759 Acc: 0.6613
# Elapsed 2673.40s, 20.25 s/epoch, 0.14 s/batch, ets 2389.85s
#
# Test set: Average loss: 0.5357, Accuracy: 467/600 (78%)
#
# Epoch: 132
# Train Loss: 0.630329 Acc: 0.6675
# Elapsed 2693.46s, 20.25 s/epoch, 0.14 s/batch, ets 2369.43s
#
# Test set: Average loss: 0.5413, Accuracy: 465/600 (78%)
#
# Epoch: 133
# Train Loss: 0.629403 Acc: 0.6779
# Elapsed 2713.70s, 20.25 s/epoch, 0.14 s/batch, ets 2349.17s
#
# Test set: Average loss: 0.5355, Accuracy: 467/600 (78%)
#
# Epoch: 134
# Train Loss: 0.639858 Acc: 0.6771
# Elapsed 2732.97s, 20.24 s/epoch, 0.13 s/batch, ets 2328.09s
#
# Test set: Average loss: 0.5557, Accuracy: 439/600 (73%)
#
# Epoch: 135
# Train Loss: 0.649515 Acc: 0.6642
# Elapsed 2752.97s, 20.24 s/epoch, 0.13 s/batch, ets 2307.63s
#
# Test set: Average loss: 0.5449, Accuracy: 462/600 (77%)
#
# Epoch: 136
# Train Loss: 0.636944 Acc: 0.6733
# Elapsed 2773.06s, 20.24 s/epoch, 0.13 s/batch, ets 2287.27s
#
# Test set: Average loss: 0.5399, Accuracy: 471/600 (78%)
#
# Epoch: 137
# Train Loss: 0.626992 Acc: 0.6800
# Elapsed 2792.72s, 20.24 s/epoch, 0.13 s/batch, ets 2266.55s
#
# Test set: Average loss: 0.5412, Accuracy: 442/600 (74%)
#
# Epoch: 138
# Train Loss: 0.624738 Acc: 0.6696
# Elapsed 2813.19s, 20.24 s/epoch, 0.13 s/batch, ets 2246.50s
#
# Test set: Average loss: 0.5556, Accuracy: 461/600 (77%)
#
# Epoch: 139
# Train Loss: 0.624848 Acc: 0.6796
# Elapsed 2832.85s, 20.23 s/epoch, 0.13 s/batch, ets 2225.81s
#
# Test set: Average loss: 0.5485, Accuracy: 462/600 (77%)
#
# Epoch: 140
# Train Loss: 0.638307 Acc: 0.6725
# Elapsed 2853.02s, 20.23 s/epoch, 0.13 s/batch, ets 2205.53s
#
# Test set: Average loss: 0.5551, Accuracy: 450/600 (75%)
#
# Epoch: 141
# Train Loss: 0.623481 Acc: 0.6783
# Elapsed 2873.34s, 20.23 s/epoch, 0.13 s/batch, ets 2185.36s
#
# Test set: Average loss: 0.5443, Accuracy: 471/600 (78%)
#
# Epoch: 142
# Train Loss: 0.618825 Acc: 0.6833
# Elapsed 2892.77s, 20.23 s/epoch, 0.13 s/batch, ets 2164.52s
#
# Test set: Average loss: 0.5555, Accuracy: 461/600 (77%)
#
# Epoch: 143
# Train Loss: 0.629234 Acc: 0.6779
# Elapsed 2912.97s, 20.23 s/epoch, 0.13 s/batch, ets 2144.27s
#
# Test set: Average loss: 0.5548, Accuracy: 464/600 (77%)
#
# Epoch: 144
# Train Loss: 0.629272 Acc: 0.6679
# Elapsed 2933.62s, 20.23 s/epoch, 0.13 s/batch, ets 2124.35s
#
# Test set: Average loss: 0.5402, Accuracy: 461/600 (77%)
#
# Epoch: 145
# Train Loss: 0.651365 Acc: 0.6650
# Elapsed 2953.40s, 20.23 s/epoch, 0.13 s/batch, ets 2103.79s
#
# Test set: Average loss: 0.5316, Accuracy: 463/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 146
# Train Loss: 0.626604 Acc: 0.6787
# Elapsed 2974.26s, 20.23 s/epoch, 0.13 s/batch, ets 2084.01s
#
# Test set: Average loss: 0.5414, Accuracy: 465/600 (78%)
#
# Epoch: 147
# Train Loss: 0.610966 Acc: 0.6913
# Elapsed 2994.24s, 20.23 s/epoch, 0.13 s/batch, ets 2063.60s
#
# Test set: Average loss: 0.5409, Accuracy: 452/600 (75%)
#
# Epoch: 148
# Train Loss: 0.629090 Acc: 0.6733
# Elapsed 3014.11s, 20.23 s/epoch, 0.13 s/batch, ets 2043.12s
#
# Test set: Average loss: 0.5514, Accuracy: 466/600 (78%)
#
# Epoch: 149
# Train Loss: 0.611633 Acc: 0.6983
# Elapsed 3034.37s, 20.23 s/epoch, 0.13 s/batch, ets 2022.91s
#
# Test set: Average loss: 0.5385, Accuracy: 447/600 (74%)
#
# Epoch: 150
# Train Loss: 0.626214 Acc: 0.6663
# Elapsed 3054.08s, 20.23 s/epoch, 0.13 s/batch, ets 2002.34s
#
# Test set: Average loss: 0.5389, Accuracy: 466/600 (78%)
#
# Epoch: 151
# Train Loss: 0.621485 Acc: 0.6817
# Elapsed 3074.23s, 20.23 s/epoch, 0.13 s/batch, ets 1982.07s
#
# Test set: Average loss: 0.5366, Accuracy: 454/600 (76%)
#
# Epoch: 152
# Train Loss: 0.605795 Acc: 0.6967
# Elapsed 3094.39s, 20.22 s/epoch, 0.13 s/batch, ets 1961.80s
#
# Test set: Average loss: 0.5312, Accuracy: 469/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 153
# Train Loss: 0.626551 Acc: 0.6617
# Elapsed 3114.57s, 20.22 s/epoch, 0.13 s/batch, ets 1941.55s
#
# Test set: Average loss: 0.5420, Accuracy: 466/600 (78%)
#
# Epoch: 154
# Train Loss: 0.610317 Acc: 0.7000
# Elapsed 3134.85s, 20.22 s/epoch, 0.13 s/batch, ets 1921.36s
#
# Test set: Average loss: 0.5394, Accuracy: 466/600 (78%)
#
# Epoch: 155
# Train Loss: 0.605368 Acc: 0.6967
# Elapsed 3155.35s, 20.23 s/epoch, 0.13 s/batch, ets 1901.30s
#
# Test set: Average loss: 0.5355, Accuracy: 473/600 (79%)
#
# Epoch: 156
# Train Loss: 0.633360 Acc: 0.6754
# Elapsed 3175.21s, 20.22 s/epoch, 0.13 s/batch, ets 1880.86s
#
# Test set: Average loss: 0.5420, Accuracy: 470/600 (78%)
#
# Epoch: 157
# Train Loss: 0.626933 Acc: 0.6679
# Elapsed 3195.61s, 20.23 s/epoch, 0.13 s/batch, ets 1860.74s
#
# Test set: Average loss: 0.5288, Accuracy: 470/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 158
# Train Loss: 0.612295 Acc: 0.6925
# Elapsed 3215.58s, 20.22 s/epoch, 0.13 s/batch, ets 1840.37s
#
# Test set: Average loss: 0.5289, Accuracy: 462/600 (77%)
#
# Epoch: 159
# Train Loss: 0.627274 Acc: 0.6837
# Elapsed 3235.81s, 20.22 s/epoch, 0.13 s/batch, ets 1820.14s
#
# Test set: Average loss: 0.5350, Accuracy: 466/600 (78%)
#
# Epoch: 160
# Train Loss: 0.615655 Acc: 0.6821
# Elapsed 3256.33s, 20.23 s/epoch, 0.13 s/batch, ets 1800.08s
#
# Test set: Average loss: 0.5334, Accuracy: 475/600 (79%)
#
# Epoch: 161
# Train Loss: 0.614969 Acc: 0.6837
# Elapsed 3275.78s, 20.22 s/epoch, 0.13 s/batch, ets 1779.43s
#
# Test set: Average loss: 0.5412, Accuracy: 469/600 (78%)
#
# Epoch: 162
# Train Loss: 0.608307 Acc: 0.6900
# Elapsed 3295.90s, 20.22 s/epoch, 0.13 s/batch, ets 1759.16s
#
# Test set: Average loss: 0.5237, Accuracy: 463/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 163
# Train Loss: 0.623193 Acc: 0.6708
# Elapsed 3316.54s, 20.22 s/epoch, 0.13 s/batch, ets 1739.16s
#
# Test set: Average loss: 0.5268, Accuracy: 476/600 (79%)
#
# Epoch: 164
# Train Loss: 0.614192 Acc: 0.6754
# Elapsed 3335.91s, 20.22 s/epoch, 0.13 s/batch, ets 1718.50s
#
# Test set: Average loss: 0.5246, Accuracy: 470/600 (78%)
#
# Epoch: 165
# Train Loss: 0.604426 Acc: 0.6892
# Elapsed 3355.96s, 20.22 s/epoch, 0.13 s/batch, ets 1698.20s
#
# Test set: Average loss: 0.5148, Accuracy: 458/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 166
# Train Loss: 0.623820 Acc: 0.6742
# Elapsed 3375.69s, 20.21 s/epoch, 0.13 s/batch, ets 1677.74s
#
# Test set: Average loss: 0.5184, Accuracy: 480/600 (80%)
#
# Epoch: 167
# Train Loss: 0.625739 Acc: 0.6687
# Elapsed 3395.78s, 20.21 s/epoch, 0.13 s/batch, ets 1657.46s
#
# Test set: Average loss: 0.5303, Accuracy: 475/600 (79%)
#
# Epoch: 168
# Train Loss: 0.613774 Acc: 0.6796
# Elapsed 3415.87s, 20.21 s/epoch, 0.13 s/batch, ets 1637.19s
#
# Test set: Average loss: 0.5211, Accuracy: 463/600 (77%)
#
# Epoch: 169
# Train Loss: 0.610716 Acc: 0.6883
# Elapsed 3435.74s, 20.21 s/epoch, 0.13 s/batch, ets 1616.82s
#
# Test set: Average loss: 0.5245, Accuracy: 473/600 (79%)
#
# Epoch: 170
# Train Loss: 0.636720 Acc: 0.6704
# Elapsed 3456.01s, 20.21 s/epoch, 0.13 s/batch, ets 1596.63s
#
# Test set: Average loss: 0.5319, Accuracy: 471/600 (78%)
#
# Epoch: 171
# Train Loss: 0.618159 Acc: 0.6871
# Elapsed 3476.68s, 20.21 s/epoch, 0.13 s/batch, ets 1576.64s
#
# Test set: Average loss: 0.5359, Accuracy: 457/600 (76%)
#
# Epoch: 172
# Train Loss: 0.614534 Acc: 0.6725
# Elapsed 3496.40s, 20.21 s/epoch, 0.13 s/batch, ets 1556.20s
#
# Test set: Average loss: 0.5403, Accuracy: 463/600 (77%)
#
# Epoch: 173
# Train Loss: 0.628101 Acc: 0.6783
# Elapsed 3516.79s, 20.21 s/epoch, 0.13 s/batch, ets 1536.07s
#
# Test set: Average loss: 0.5514, Accuracy: 467/600 (78%)
#
# Epoch: 174
# Train Loss: 0.620319 Acc: 0.6763
# Elapsed 3536.71s, 20.21 s/epoch, 0.13 s/batch, ets 1515.73s
#
# Test set: Average loss: 0.5240, Accuracy: 468/600 (78%)
#
# Epoch: 175
# Train Loss: 0.608567 Acc: 0.6821
# Elapsed 3556.38s, 20.21 s/epoch, 0.13 s/batch, ets 1495.30s
#
# Test set: Average loss: 0.5312, Accuracy: 455/600 (76%)
#
# Epoch: 176
# Train Loss: 0.616135 Acc: 0.6887
# Elapsed 3576.67s, 20.21 s/epoch, 0.13 s/batch, ets 1475.12s
#
# Test set: Average loss: 0.5325, Accuracy: 467/600 (78%)
#
# Epoch: 177
# Train Loss: 0.615262 Acc: 0.6729
# Elapsed 3595.94s, 20.20 s/epoch, 0.13 s/batch, ets 1454.54s
#
# Test set: Average loss: 0.5353, Accuracy: 450/600 (75%)
#
# Epoch: 178
# Train Loss: 0.619784 Acc: 0.6858
# Elapsed 3616.04s, 20.20 s/epoch, 0.13 s/batch, ets 1434.30s
#
# Test set: Average loss: 0.5288, Accuracy: 478/600 (80%)
#
# Epoch: 179
# Train Loss: 0.590226 Acc: 0.6883
# Elapsed 3635.98s, 20.20 s/epoch, 0.13 s/batch, ets 1413.99s
#
# Test set: Average loss: 0.5411, Accuracy: 460/600 (77%)
#
# Epoch: 180
# Train Loss: 0.620829 Acc: 0.6763
# Elapsed 3655.44s, 20.20 s/epoch, 0.13 s/batch, ets 1393.51s
#
# Test set: Average loss: 0.5261, Accuracy: 469/600 (78%)
#
# Epoch: 181
# Train Loss: 0.611026 Acc: 0.6746
# Elapsed 3675.96s, 20.20 s/epoch, 0.13 s/batch, ets 1373.44s
#
# Test set: Average loss: 0.5408, Accuracy: 457/600 (76%)
#
# Epoch: 182
# Train Loss: 0.621583 Acc: 0.6717
# Elapsed 3696.15s, 20.20 s/epoch, 0.13 s/batch, ets 1353.23s
#
# Test set: Average loss: 0.5432, Accuracy: 474/600 (79%)
#
# Epoch: 183
# Train Loss: 0.597901 Acc: 0.6954
# Elapsed 3715.51s, 20.19 s/epoch, 0.13 s/batch, ets 1332.74s
#
# Test set: Average loss: 0.5319, Accuracy: 484/600 (81%)
#
# Epoch: 184
# Train Loss: 0.624458 Acc: 0.6804
# Elapsed 3735.57s, 20.19 s/epoch, 0.13 s/batch, ets 1312.50s
#
# Test set: Average loss: 0.5270, Accuracy: 477/600 (80%)
#
# Epoch: 185
# Train Loss: 0.603361 Acc: 0.6879
# Elapsed 3755.39s, 20.19 s/epoch, 0.13 s/batch, ets 1292.18s
#
# Test set: Average loss: 0.5321, Accuracy: 473/600 (79%)
#
# Epoch: 186
# Train Loss: 0.614928 Acc: 0.6783
# Elapsed 3775.94s, 20.19 s/epoch, 0.13 s/batch, ets 1272.11s
#
# Test set: Average loss: 0.5363, Accuracy: 472/600 (79%)
#
# Epoch: 187
# Train Loss: 0.615085 Acc: 0.6929
# Elapsed 3796.28s, 20.19 s/epoch, 0.13 s/batch, ets 1251.96s
#
# Test set: Average loss: 0.5305, Accuracy: 464/600 (77%)
#
# Epoch: 188
# Train Loss: 0.599922 Acc: 0.6908
# Elapsed 3816.00s, 20.19 s/epoch, 0.13 s/batch, ets 1231.62s
#
# Test set: Average loss: 0.5376, Accuracy: 470/600 (78%)
#
# Epoch: 189
# Train Loss: 0.624992 Acc: 0.6779
# Elapsed 3836.57s, 20.19 s/epoch, 0.13 s/batch, ets 1211.55s
#
# Test set: Average loss: 0.5361, Accuracy: 467/600 (78%)
#
# Epoch: 190
# Train Loss: 0.596237 Acc: 0.6921
# Elapsed 3856.93s, 20.19 s/epoch, 0.13 s/batch, ets 1191.41s
#
# Test set: Average loss: 0.5421, Accuracy: 461/600 (77%)
#
# Epoch: 191
# Train Loss: 0.598719 Acc: 0.6987
# Elapsed 3876.58s, 20.19 s/epoch, 0.13 s/batch, ets 1171.05s
#
# Test set: Average loss: 0.5311, Accuracy: 476/600 (79%)
#
# Epoch: 192
# Train Loss: 0.600945 Acc: 0.6933
# Elapsed 3896.50s, 20.19 s/epoch, 0.13 s/batch, ets 1150.78s
#
# Test set: Average loss: 0.5299, Accuracy: 481/600 (80%)
#
# Epoch: 193
# Train Loss: 0.604692 Acc: 0.6967
# Elapsed 3916.48s, 20.19 s/epoch, 0.13 s/batch, ets 1130.53s
#
# Test set: Average loss: 0.5329, Accuracy: 475/600 (79%)
#
# Epoch: 194
# Train Loss: 0.617980 Acc: 0.6900
# Elapsed 3936.97s, 20.19 s/epoch, 0.13 s/batch, ets 1110.43s
#
# Test set: Average loss: 0.5506, Accuracy: 463/600 (77%)
#
# Epoch: 195
# Train Loss: 0.599747 Acc: 0.6925
# Elapsed 3957.07s, 20.19 s/epoch, 0.13 s/batch, ets 1090.21s
#
# Test set: Average loss: 0.5327, Accuracy: 468/600 (78%)
#
# Epoch: 196
# Train Loss: 0.599455 Acc: 0.6875
# Elapsed 3976.92s, 20.19 s/epoch, 0.13 s/batch, ets 1069.93s
#
# Test set: Average loss: 0.5333, Accuracy: 468/600 (78%)
#
# Epoch: 197
# Train Loss: 0.601847 Acc: 0.6854
# Elapsed 3997.26s, 20.19 s/epoch, 0.13 s/batch, ets 1049.79s
#
# Test set: Average loss: 0.5367, Accuracy: 478/600 (80%)
#
# Epoch: 198
# Train Loss: 0.609940 Acc: 0.6800
# Elapsed 4017.50s, 20.19 s/epoch, 0.13 s/batch, ets 1029.61s
#
# Test set: Average loss: 0.5207, Accuracy: 473/600 (79%)
#
# Epoch: 199
# Train Loss: 0.619415 Acc: 0.6846
# Elapsed 4037.08s, 20.19 s/epoch, 0.13 s/batch, ets 1009.27s
#
# Test set: Average loss: 0.5271, Accuracy: 466/600 (78%)
#
# Epoch: 200
# Train Loss: 0.612904 Acc: 0.6867
# Elapsed 4057.47s, 20.19 s/epoch, 0.13 s/batch, ets 989.14s
#
# Test set: Average loss: 0.5345, Accuracy: 469/600 (78%)
#
# Epoch: 201
# Train Loss: 0.611100 Acc: 0.6875
# Elapsed 4077.29s, 20.18 s/epoch, 0.13 s/batch, ets 968.86s
#
# Test set: Average loss: 0.5267, Accuracy: 469/600 (78%)
#
# Epoch: 202
# Train Loss: 0.596419 Acc: 0.6825
# Elapsed 4098.08s, 20.19 s/epoch, 0.13 s/batch, ets 948.82s
#
# Test set: Average loss: 0.5249, Accuracy: 472/600 (79%)
#
# Epoch: 203
# Train Loss: 0.596402 Acc: 0.6850
# Elapsed 4118.74s, 20.19 s/epoch, 0.13 s/batch, ets 928.74s
#
# Test set: Average loss: 0.5191, Accuracy: 475/600 (79%)
#
# Epoch: 204
# Train Loss: 0.615620 Acc: 0.6879
# Elapsed 4138.50s, 20.19 s/epoch, 0.13 s/batch, ets 908.45s
#
# Test set: Average loss: 0.5258, Accuracy: 475/600 (79%)
#
# Epoch: 205
# Train Loss: 0.610910 Acc: 0.6933
# Elapsed 4159.81s, 20.19 s/epoch, 0.13 s/batch, ets 888.50s
#
# Test set: Average loss: 0.5298, Accuracy: 474/600 (79%)
#
# Epoch: 206
# Train Loss: 0.624602 Acc: 0.6742
# Elapsed 4181.11s, 20.20 s/epoch, 0.13 s/batch, ets 868.54s
#
# Test set: Average loss: 0.5305, Accuracy: 477/600 (80%)
#
# Epoch: 207
# Train Loss: 0.619338 Acc: 0.6783
# Elapsed 4202.37s, 20.20 s/epoch, 0.13 s/batch, ets 848.56s
#
# Test set: Average loss: 0.5243, Accuracy: 462/600 (77%)
#
# Epoch: 208
# Train Loss: 0.612009 Acc: 0.6850
# Elapsed 4223.54s, 20.21 s/epoch, 0.13 s/batch, ets 828.54s
#
# Test set: Average loss: 0.5500, Accuracy: 469/600 (78%)
#
# Epoch: 209
# Train Loss: 0.608343 Acc: 0.6996
# Elapsed 4244.53s, 20.21 s/epoch, 0.13 s/batch, ets 808.48s
#
# Test set: Average loss: 0.5453, Accuracy: 462/600 (77%)
#
# Epoch: 210
# Train Loss: 0.612806 Acc: 0.6925
# Elapsed 4264.77s, 20.21 s/epoch, 0.13 s/batch, ets 788.27s
#
# Test set: Average loss: 0.5159, Accuracy: 472/600 (79%)
#
# Epoch: 211
# Train Loss: 0.597922 Acc: 0.6937
# Elapsed 4285.47s, 20.21 s/epoch, 0.13 s/batch, ets 768.15s
#
# Test set: Average loss: 0.5429, Accuracy: 471/600 (78%)
#
# Epoch: 212
# Train Loss: 0.605861 Acc: 0.6875
# Elapsed 4305.87s, 20.22 s/epoch, 0.13 s/batch, ets 747.97s
#
# Test set: Average loss: 0.5117, Accuracy: 478/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 213
# Train Loss: 0.615244 Acc: 0.6842
# Elapsed 4326.16s, 20.22 s/epoch, 0.13 s/batch, ets 727.77s
#
# Test set: Average loss: 0.5206, Accuracy: 483/600 (80%)
#
# Epoch: 214
# Train Loss: 0.602406 Acc: 0.6933
# Elapsed 4346.86s, 20.22 s/epoch, 0.13 s/batch, ets 707.63s
#
# Test set: Average loss: 0.5278, Accuracy: 474/600 (79%)
#
# Epoch: 215
# Train Loss: 0.589774 Acc: 0.7004
# Elapsed 4367.38s, 20.22 s/epoch, 0.13 s/batch, ets 687.46s
#
# Test set: Average loss: 0.5288, Accuracy: 453/600 (76%)
#
# Epoch: 216
# Train Loss: 0.614086 Acc: 0.6933
# Elapsed 4387.11s, 20.22 s/epoch, 0.13 s/batch, ets 667.16s
#
# Test set: Average loss: 0.5306, Accuracy: 479/600 (80%)
#
# Epoch: 217
# Train Loss: 0.611974 Acc: 0.6971
# Elapsed 4407.72s, 20.22 s/epoch, 0.13 s/batch, ets 647.00s
#
# Test set: Average loss: 0.5205, Accuracy: 481/600 (80%)
#
# Epoch: 218
# Train Loss: 0.604303 Acc: 0.6813
# Elapsed 4427.56s, 20.22 s/epoch, 0.13 s/batch, ets 626.73s
#
# Test set: Average loss: 0.5307, Accuracy: 459/600 (76%)
#
# Epoch: 219
# Train Loss: 0.609866 Acc: 0.6913
# Elapsed 4447.84s, 20.22 s/epoch, 0.13 s/batch, ets 606.52s
#
# Test set: Average loss: 0.5336, Accuracy: 462/600 (77%)
#
# Epoch: 220
# Train Loss: 0.610438 Acc: 0.6929
# Elapsed 4468.35s, 20.22 s/epoch, 0.13 s/batch, ets 586.34s
#
# Test set: Average loss: 0.5410, Accuracy: 468/600 (78%)
#
# Epoch: 221
# Train Loss: 0.620454 Acc: 0.6900
# Elapsed 4488.12s, 20.22 s/epoch, 0.13 s/batch, ets 566.07s
#
# Test set: Average loss: 0.5489, Accuracy: 450/600 (75%)
#
# Epoch: 222
# Train Loss: 0.615901 Acc: 0.6854
# Elapsed 4508.57s, 20.22 s/epoch, 0.13 s/batch, ets 545.88s
#
# Test set: Average loss: 0.5351, Accuracy: 472/600 (79%)
#
# Epoch: 223
# Train Loss: 0.601353 Acc: 0.7008
# Elapsed 4529.41s, 20.22 s/epoch, 0.13 s/batch, ets 525.74s
#
# Test set: Average loss: 0.5376, Accuracy: 452/600 (75%)
#
# Epoch: 224
# Train Loss: 0.603344 Acc: 0.6875
# Elapsed 4549.11s, 20.22 s/epoch, 0.13 s/batch, ets 505.46s
#
# Test set: Average loss: 0.5305, Accuracy: 451/600 (75%)
#
# Epoch: 225
# Train Loss: 0.600603 Acc: 0.7092
# Elapsed 4569.65s, 20.22 s/epoch, 0.13 s/batch, ets 485.27s
#
# Test set: Average loss: 0.5226, Accuracy: 470/600 (78%)
#
# Epoch: 226
# Train Loss: 0.609496 Acc: 0.6908
# Elapsed 4589.88s, 20.22 s/epoch, 0.13 s/batch, ets 465.05s
#
# Test set: Average loss: 0.5158, Accuracy: 459/600 (76%)
#
# Epoch: 227
# Train Loss: 0.610979 Acc: 0.6950
# Elapsed 4609.22s, 20.22 s/epoch, 0.13 s/batch, ets 444.75s
#
# Test set: Average loss: 0.5197, Accuracy: 457/600 (76%)
#
# Epoch: 228
# Train Loss: 0.607923 Acc: 0.6929
# Elapsed 4629.22s, 20.21 s/epoch, 0.13 s/batch, ets 424.51s
#
# Test set: Average loss: 0.5219, Accuracy: 466/600 (78%)
#
# Epoch: 229
# Train Loss: 0.607653 Acc: 0.6929
# Elapsed 4649.22s, 20.21 s/epoch, 0.13 s/batch, ets 404.28s
#
# Test set: Average loss: 0.5315, Accuracy: 471/600 (78%)
#
# Epoch: 230
# Train Loss: 0.603891 Acc: 0.6892
# Elapsed 4669.18s, 20.21 s/epoch, 0.13 s/batch, ets 384.05s
#
# Test set: Average loss: 0.5315, Accuracy: 471/600 (78%)
#
# Epoch: 231
# Train Loss: 0.607085 Acc: 0.6950
# Elapsed 4689.36s, 20.21 s/epoch, 0.13 s/batch, ets 363.83s
#
# Test set: Average loss: 0.5195, Accuracy: 481/600 (80%)
#
# Epoch: 232
# Train Loss: 0.598942 Acc: 0.7029
# Elapsed 4708.85s, 20.21 s/epoch, 0.13 s/batch, ets 343.56s
#
# Test set: Average loss: 0.5133, Accuracy: 478/600 (80%)
#
# Epoch: 233
# Train Loss: 0.607213 Acc: 0.6900
# Elapsed 4729.12s, 20.21 s/epoch, 0.13 s/batch, ets 323.36s
#
# Test set: Average loss: 0.5098, Accuracy: 479/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 234
# Train Loss: 0.606502 Acc: 0.6950
# Elapsed 4749.64s, 20.21 s/epoch, 0.13 s/batch, ets 303.17s
#
# Test set: Average loss: 0.5171, Accuracy: 476/600 (79%)
#
# Epoch: 235
# Train Loss: 0.617411 Acc: 0.6796
# Elapsed 4769.10s, 20.21 s/epoch, 0.13 s/batch, ets 282.91s
#
# Test set: Average loss: 0.5100, Accuracy: 476/600 (79%)
#
# Epoch: 236
# Train Loss: 0.604895 Acc: 0.6946
# Elapsed 4789.23s, 20.21 s/epoch, 0.13 s/batch, ets 262.70s
#
# Test set: Average loss: 0.5131, Accuracy: 478/600 (80%)
#
# Epoch: 237
# Train Loss: 0.591318 Acc: 0.6933
# Elapsed 4808.66s, 20.20 s/epoch, 0.13 s/batch, ets 242.45s
#
# Test set: Average loss: 0.5168, Accuracy: 480/600 (80%)
#
# Epoch: 238
# Train Loss: 0.579011 Acc: 0.7108
# Elapsed 4829.11s, 20.21 s/epoch, 0.13 s/batch, ets 222.26s
#
# Test set: Average loss: 0.5184, Accuracy: 473/600 (79%)
#
# Epoch: 239
# Train Loss: 0.602307 Acc: 0.6787
# Elapsed 4849.28s, 20.21 s/epoch, 0.13 s/batch, ets 202.05s
#
# Test set: Average loss: 0.5240, Accuracy: 474/600 (79%)
#
# Epoch: 240
# Train Loss: 0.589579 Acc: 0.6937
# Elapsed 4868.81s, 20.20 s/epoch, 0.13 s/batch, ets 181.82s
#
# Test set: Average loss: 0.5107, Accuracy: 473/600 (79%)
#
# Epoch: 241
# Train Loss: 0.591516 Acc: 0.6887
# Elapsed 4889.15s, 20.20 s/epoch, 0.13 s/batch, ets 161.62s
#
# Test set: Average loss: 0.5142, Accuracy: 473/600 (79%)
#
# Epoch: 242
# Train Loss: 0.603690 Acc: 0.6917
# Elapsed 4909.24s, 20.20 s/epoch, 0.13 s/batch, ets 141.42s
#
# Test set: Average loss: 0.5085, Accuracy: 481/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 243
# Train Loss: 0.590343 Acc: 0.7013
# Elapsed 4928.92s, 20.20 s/epoch, 0.13 s/batch, ets 121.20s
#
# Test set: Average loss: 0.5249, Accuracy: 474/600 (79%)
#
# Epoch: 244
# Train Loss: 0.596135 Acc: 0.6946
# Elapsed 4949.28s, 20.20 s/epoch, 0.13 s/batch, ets 101.01s
#
# Test set: Average loss: 0.5122, Accuracy: 482/600 (80%)
#
# Epoch: 245
# Train Loss: 0.590608 Acc: 0.7025
# Elapsed 4968.63s, 20.20 s/epoch, 0.13 s/batch, ets 80.79s
#
# Test set: Average loss: 0.5187, Accuracy: 478/600 (80%)
#
# Epoch: 246
# Train Loss: 0.596899 Acc: 0.6904
# Elapsed 4988.62s, 20.20 s/epoch, 0.13 s/batch, ets 60.59s
#
# Test set: Average loss: 0.5098, Accuracy: 464/600 (77%)
#
# Epoch: 247
# Train Loss: 0.594815 Acc: 0.6925
# Elapsed 5008.67s, 20.20 s/epoch, 0.13 s/batch, ets 40.39s
#
# Test set: Average loss: 0.5078, Accuracy: 473/600 (79%)
#
# Model Improved. Saving the Model...
#
# Epoch: 248
# Train Loss: 0.599524 Acc: 0.6979
# Elapsed 5028.46s, 20.19 s/epoch, 0.13 s/batch, ets 20.19s
#
# Test set: Average loss: 0.5341, Accuracy: 465/600 (78%)
#
# Epoch: 249
# Train Loss: 0.592803 Acc: 0.6929
# Elapsed 5049.05s, 20.20 s/epoch, 0.13 s/batch, ets 0.00s
#
# Test set: Average loss: 0.5140, Accuracy: 478/600 (80%)
#
# Total time: 5051.80, Best Loss: 0.508

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">Step 5. Sample Prediction</font><a name="step5"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    data = batch_input.to(device)
    
    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %% [markdown]
# # <font style="color:red">Step 6. Display Confusion Matrix [10 Points]</font><a name="step6"></a>
#
# Display the confusion matrix for the above problem(Refer to the earlier lectures on Performance Metrics).
#
#
# The output should resemble this:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/02/c3_w5_sample_confusion_matrix.png' width=600>

# %%
training_configuration = TrainingConfiguration()

# data loader
train_loader, test_loader = get_data(
    batch_size=16,
    data_root=training_configuration.data_root,
    num_workers=2,
    data_augmentation=True
)


model.eval()
test_loss = 0
count_corect_predictions = 0
y =[]
y_pred =[]
for data, target in test_loader:
    indx_target = target.clone()
    data = data.to(train_config.device)

    target = target.to(train_config.device)

    with torch.no_grad():
        output = model(data)

    # add loss for each mini batch
    test_loss += F.cross_entropy(output, target).item()

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the index of the max probability
    pred = prob.data.max(dim=1)[1] 
    
    # resultados
    #y.append(indx_target.tolist())
    #y_pred.append(pred.tolist())
    y = y + indx_target.tolist()
    y_pred = y_pred + pred.tolist()

    # add correct prediction count
    count_corect_predictions += pred.cpu().eq(indx_target).sum()

# average over number of mini-batches
test_loss = test_loss / len(test_loader)  

# average over number of dataset
accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['cat','dog', 'panda'])
disp.plot()

# %% [markdown]
# Upon completing the assignment,  <font style="color:red">pload the 2 notebooks and the models folder on the portal for feedback.</font>
